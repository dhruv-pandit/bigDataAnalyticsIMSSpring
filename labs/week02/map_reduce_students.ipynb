# %% [markdown]
# # MapReduce in Python
#
# This notebook provides a hands-on introduction to the **MapReduce** paradigm using Python.
# We build the three core functions **from scratch** — `map_func`, `shuffle_and_sort`, and `reduce_func` — and then apply them to real movie data.
#
# ### Dataset
# We will use the same dataset from last week

# %% [markdown]
# ### Part 1 — Load the Dataset

# %%
import pandas as pd
import string

# Load the dataset — adjust the relative path if needed
df = pd.read_csv("../week01/wiki_movie_plots_deduped.csv")

# Quick sanity check
print(f"Rows: {len(df):,}")
print(f"Columns: {list(df.columns)}")
df.head(3)
# Out:
# Rows: 34,886
# Columns: ['Release Year', 'Title', 'Origin/Ethnicity', 'Director', 'Cast', 'Genre', 'Wiki Page', 'Plot']
#    Release Year                          Title Origin/Ethnicity Director Cast  \
# 0          1901         Kansas Saloon Smashers         American  Unknown  NaN
# 1          1901  Love by the Light of the Moon         American  Unknown  NaN
# 2          1901        The Martyred Presidents         American  Unknown  NaN
#
#      Genre                                          Wiki Page  \
# 0  unknown  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  unknown  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  unknown  https://en.wikipedia.org/wiki/The_Martyred_Pre...
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...

# %% [markdown]
# ### Part 2 — The MapReduce Framework
#
# Before writing any task-specific logic, we build three **reusable** functions that form the backbone of every MapReduce job we will run today.
#
# | Function | Role | Input | Output |
# |---|---|---|---|
# | `map_func` | User-defined; emits key-value pairs | A single record | `[(key, value), ...]` |
# | `shuffle_and_sort` | Groups all values by key | `[(key, value), ...]` | `{key: [v1, v2, ...]}` |
# | `reduce_func` | User-defined; aggregates values per key | `{key: [values]}` | `{key: result}` |
#
# > **Why is Shuffle & Sort a separate step?**
# > In a real distributed system this is the *most expensive* network operation — every mapper on every machine ships its emitted pairs to the correct reducer node. We have one machine, but the logic is identical.

# %%
from collections import defaultdict

# ── 1. Shuffle & Sort ────────────────────────────────────────────────────────
def shuffle_and_sort(mapped_output):
    """
    Groups all emitted (key, value) pairs produced by the Map phase by their key.

    This is the crucial intermediate step between Map and Reduce.
    In a real distributed system, this involves:
      - Sorting all emitted pairs across all worker nodes
      - Shipping each key to the single reducer responsible for it
    Here we mimic that by grouping into a dictionary of lists.

    Args:
        mapped_output: a flat list of (key, value) tuples from the map phase.

    Returns:
        A dict  {key: [value1, value2, ...]}
    """
    grouped = defaultdict(list)
    for key, value in mapped_output:
        grouped[key].append(value)
    return dict(grouped)


# ── 2. Generic run_mapreduce orchestrator ────────────────────────────────────
def run_mapreduce(records, map_func, reduce_func):
    """
    Runs a full MapReduce job.

    Args:
        records   : iterable of input records (e.g. rows from a DataFrame).
        map_func  : callable(record) -> [(key, value), ...].
        reduce_func: callable(key, values) -> (key, result).

    Returns:
        List of (key, result) tuples.
    """
    # ── Map Phase ────────────────────────────────────────────────────────────
    mapped = []
    for record in records:
        mapped.extend(map_func(record))         # each record may emit many pairs

    # ── Shuffle & Sort Phase ─────────────────────────────────────────────────
    shuffled = shuffle_and_sort(mapped)

    # ── Reduce Phase ─────────────────────────────────────────────────────────
    results = []
    for key, values in shuffled.items():
        results.append(reduce_func(key, values))

    return results


print("Core MapReduce functions defined ✓")
# Out:
# Core MapReduce functions defined ✓

# %% [markdown]
# ## Part 3 — Task 1: Word Count on Movie Titles
#
# **Goal:** Count how many times each word appears across all movie titles in the dataset.
#
# This is the "Hello, World!" of MapReduce.
#
# ### The plan
#
# ```
# INPUT ROW        →  MAP                     →  SHUFFLE & SORT          →  REDUCE
# ─────────────────────────────────────────────────────────────────────────────────
# "The Dark Knight"   ("the", 1)               "the":    [1, 1, 1, ...]    ("the",    N)
#                     ("dark", 1)              "dark":   [1, 1, ...]        ("dark",   N)
#                     ("knight", 1)            "knight": [1, ...]           ("knight", N)
# ```
#
# **Preprocessing** in the mapper:
# - Strip leading/trailing whitespace
# - Convert to lowercase
# - Remove punctuation

# %%
# ── Mapper ───────────────────────────────────────────────────────────────────
def title_word_mapper(title):
    """
    Takes a single movie title (string) and emits one (word, 1) pair per word.

    Preprocessing steps:
      1. Strip whitespace
      2. Convert to lowercase (so 'The' and 'the' are treated as the same word)
      3. Remove punctuation (e.g. colons, hyphens that remain after splitting)
    """
    # Remove punctuation using str.translate — fast and readable
    title_clean = title.strip().lower().translate(
        str.maketrans("", "", string.punctuation)
    )

    # Split on whitespace and emit a (word, 1) pair for every non-empty token
    return [(word, 1) for word in title_clean.split() if word]

# ── Reducer ───────────────────────────────────────────────────────────────────
def word_count_reducer(key, values):
    """
    Receives a word (key) and a list of 1s (one per occurrence).
    Returns the (word, total_count) pair.
    """
    return (key, sum(values)) # input is going (word: 1, 1, 1, .... )

# ── Run ───────────────────────────────────────────────────────────────────────
# The 'records' we pass to run_mapreduce are the individual title strings
titles = df["Title"].dropna().tolist()

results_task1 = run_mapreduce(
    records=titles,
    map_func=title_word_mapper,
    reduce_func=word_count_reducer
)

# Sort by count descending to show the most common words first
results_task1_sorted = sorted(results_task1, key = lambda x: x[1], reverse=True)
# filter for frequently occuring words, filter (), [word for word in results if word not in []]
print("Top 20 most frequent words in movie titles:\n")
for word, count in results_task1_sorted[:20]:
    print(f"  {word:<20} {count}")
# Out:
# Top 20 most frequent words in movie titles:
#
#   the                  8672
#   of                   2699
#   a                    1219
#   in                   1015
#   and                  973
#   to                   658
#   man                  469
#   love                 449
#   on                   381
#   for                  376
#   my                   351
#   2                    305
#   night                295
#   i                    270
#   from                 257
#   girl                 229
#   you                  225
#   with                 217
#   movie                215
#   no                   211

# %% [markdown]
# The top results from Task 1 are dominated by **function words** like *"the"*, *"a"*, *"of"* — words that carry little meaning. These are called **stop words**.
#
# We will now use the [NLTK](https://www.nltk.org/) library's built-in English stop-word list to filter them out in the mapper before emitting any pairs. All that changes is the mapper — the shuffle/sort and reducer stay exactly the same. This is a key strength of the MapReduce design: **each phase is independent and swappable**.
#
# > **Why filter in the mapper?**
# > In a real cluster, filtering early (in the mapper) means less data is shipped over the network during the Shuffle phase — which is the most expensive step.

# %%
import nltk

# Download the stopwords corpus (only needs to run once per machine)
nltk.download("stopwords", quiet=True)

from nltk.corpus import stopwords

# Load into a Python set — O(1) lookup is important when filtering millions of words
STOP_WORDS = set(stopwords.words("english"))

print(f"Stop words loaded: {len(STOP_WORDS)} words")
print("Sample:", sorted(STOP_WORDS)[:10])
# Out:
# Stop words loaded: 198 words
# Sample: ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
# ── Mapper (with stop-word filtering) ────────────────────────────────────────
def title_word_mapper_no_stopwords(title):
    """
    Same as title_word_mapper, but also filters out NLTK English stop words.

    Only the mapper changes — shuffle_and_sort and word_count_reducer are reused
    exactly as defined in Part 2. This demonstrates the modularity of MapReduce.
    """
    title_clean = title.strip().lower().translate(
        str.maketrans("", "", string.punctuation)
    )

    return [
        (word, 1)
        for word in title_clean.split()
        if word and word not in STOP_WORDS
    ]


# ── Run ───────────────────────────────────────────────────────────────────────
# reducer is unchanged — we reuse word_count_reducer from Task 1
results_task1b = run_mapreduce(
    records=titles, 
    map_func=title_word_mapper_no_stopwords,
    reduce_func=word_count_reducer
)

results_task1b_sorted = sorted(results_task1b, key = lambda x: x[1], reverse=True)

print("Top 20 most frequent MEANINGFUL words in movie titles:\n")
for word, count in results_task1b_sorted[:20]:
    print(f"  {word:<20} {count}")

# ── Comparison ────────────────────────────────────────────────────────────────
print(f"\nUnique words before stop-word removal : {len(results_task1_sorted):,}")
print(f"Unique words after  stop-word removal : {len(results_task1b_sorted):,}")
print(f"Words filtered out                    : {len(results_task1_sorted) - len(results_task1b_sorted):,}")
# Out:
# Top 20 most frequent MEANINGFUL words in movie titles:
#
#   man                  469
#   love                 449
#   2                    305
#   night                295
#   girl                 229
#   movie                215
#   life                 189
#   last                 184
#   big                  177
#   story                175
#   lady                 173
#   woman                173
#   black                171
#   little               168
#   one                  166
#   mr                   161
#   time                 157
#   house                152
#   men                  144
#   day                  139
#
# Unique words before stop-word removal : 22,951
# Unique words after  stop-word removal : 22,821
# Words filtered out                    : 130

# %% [markdown]
# ## Task 2 — Movies per Decade
#
# Concept: Modifying the key before emitting.
# Map: Read the Release Year, calculate the decade (e.g., 1901 -> 1900s), and emit (Decade, 1).
# Reduce: Sum the values to get the total number of movies per decade.

# %%
# ── Mapper ───────────────────────────────────────────────────────────────────
def decade_mapper(row):
    """
    Takes a DataFrame row (as a named tuple / dict-like) and emits (decade_label, 1).

    The key transformation:  release_year  →  "1900s", "1910s", etc.
    We floor to the nearest 10 using integer division: 1901 // 10 * 10 = 1900
    """
    try:
        year = int(row['Release Year'])
        decade = (year // 10) * 10 # 1901 becomes 1900
        decade_label = f"{decade}s"

    except (ValueError, TypeError):
        decade_label = "Unknown"
    return [(decade_label, 1)]
# ── Reducer ───────────────────────────────────────────────────────────────────
def count_reducer(key, values):
    """Generic count reducer — sums a list of 1s."""
    return (key, sum(values))
# ── Run ───────────────────────────────────────────────────────────────────────
# Pass rows as dicts so the mapper can access columns by name
rows = df.to_dict(orient="records")

results_task2 = run_mapreduce(
    records=rows,
    map_func=decade_mapper,
    reduce_func=count_reducer
)
# Sort chronologically
results_task2_sorted = sorted(results_task2, key=lambda x: x[1], reverse=True)

print("Number of movies per decade:\n")
for decade, count in results_task2_sorted:
    print(f"  {decade:<10} {count}")
# Out:
# Number of movies per decade:
#
#   2010s      6694
#   2000s      5866
#   1990s      4468
#   1950s      3414
#   1980s      3219
#   1940s      2919
#   1970s      2519
#   1960s      2497
#   1930s      2310
#   1920s      671
#   1910s      283
#   1900s      26

# %% [markdown]
# ## Task 3 — Genre → Movie Title Inverted Index
#
# - **Concept**: Aggregating data into a list rather than a mathematical sum.
# - **Map**: Read Genre and Title. Emit (Genre, Title).
# - **Reduce**: Instead of adding numbers, append the titles into a list. Emit (Genre, [Title1, Title2, ...]).

# %%
# ── Mapper ───────────────────────────────────────────────────────────────────
def genre_title_mapper(row):
    """
    Emits (genre, title) — one pair per row.
    Normalises the genre label to lowercase and strips whitespace.
    """
    genre = str(row.get("Genre", "unknown")).strip().lower()
    title = str(row.get("Title", "")).strip()
    return [(genre, title)]
# ── Reducer ───────────────────────────────────────────────────────────────────
def list_collect_reducer(key, values):
    """
    Instead of summing, we keep all values as a sorted list.
    This is fundamentally different from all previous reducers.
    """
    return (key, sorted(values)) 
# ── Run ───────────────────────────────────────────────────────────────────────
results_task3 = run_mapreduce(
    records = rows, 
    map_func=genre_title_mapper,
    reduce_func=list_collect_reducer
)
# Sort by genre name for readability
results_task3_sorted = sorted(results_task3, key=lambda x: len(x[1]), reverse=True)

print("Inverted index — Genre → Movie Titles (showing first 3 titles per genre):\n")
for genre, titles in results_task3_sorted:
    preview = titles[:3]
    print(f"  {genre:<20}  ({len(titles):,} movies)  e.g. {preview}")
# Out:
# Inverted index — Genre → Movie Titles (showing first 3 titles per genre):
#
#   unknown               (6,083 movies)  e.g. ['$ aka Dollars', "'71", "'Gator Bait"]
#   drama                 (5,991 movies)  e.g. ["'68", "'Til We Meet Again", "'night, Mother"]
#   comedy                (4,398 movies)  e.g. ["'Moms' Night Out", "'Neath Brooklyn Bridge", '1,000 Dollars a Minute']
#   horror                (1,172 movies)  e.g. ['12/12/12', '13 Eerie', '13 Sins']
#   action                (1,119 movies)  e.g. ["'Gator Bait II: Cajun Justice", '...tick...tick...tick...', '10 to Midnight']
#   thriller              (984 movies)  e.g. ['"Pimpernel" Smith', '10 Kalpanakal', '100 Days']
#   romance               (940 movies)  e.g. ['100 Days of Love', '100% Love', '100% Love']
#   western               (865 movies)  e.g. ['100 Rifles', '3 Godfathers', '3:10 to Yuma']
#   crime                 (568 movies)  e.g. ['10 Rillington Place', '12', '36 Hours']
#   adventure             (527 movies)  e.g. ['10,000 BC', '20,000 Leagues Under the Sea', 'A Far Off Place']
#   musical               (467 movies)  e.g. ['1776', "3 Chains o' Gold", '42nd Street']
#   romantic comedy       (465 movies)  e.g. ['(500) Days of Summer', '10 Things I Hate About You', '27 Dresses']
#   crime drama           (464 movies)  e.g. ['.45', '11:14', '16 Blocks']
#   science fiction       (418 movies)  e.g. ['20 Million Miles to Earth', '2001: A Space Odyssey', '2002']
#   film noir             (345 movies)  e.g. ['99 River Street', 'A Bullet for Joey', 'A Dangerous Profession']
#   mystery               (310 movies)  e.g. ['70,000 Witnesses', '813', 'A Close Call for Boston Blackie']
#   war                   (273 movies)  e.g. ['13 Men and a Gun', '1971', '633 Squadron']
#   animation             (265 movies)  e.g. ['$9.99', '8 Ball Bunny', 'A Bear For Punishment']
#   comedy, drama         (238 movies)  e.g. ['...All the Marbles', '13 Moons', '1987']
#   sci-fi                (221 movies)  e.g. ['4D Man', 'Alien 3', 'Android']
#   family                (217 movies)  e.g. ['2 Penkuttikal', 'A Dog of Flanders', "A Dog's Purpose"]
#   fantasy               (204 movies)  e.g. ['300: Rise of an Empire', '7 Faces of Dr. Lao', 'A Kiss for Cinderella']
#   animated              (195 movies)  e.g. ["101 Dalmatians II: Patch's London Adventure", 'A Goofy Movie', 'A Mouse in the House']
#   musical comedy        (154 movies)  e.g. ['3 Ring Circus', "A Connecticut Yankee in King Arthur's Court", 'A Funny Thing Happened on the Way to the Forum']
#   comedy-drama          (137 movies)  e.g. ['2 Frogs in the West', '50/50', 'A Thousand Words']
#   biography             (136 movies)  e.g. ["A Dispatch from Reuter's", 'A Song to Remember', 'Abu Zayd al-Hilali']
#   anime                 (112 movies)  e.g. ['.hack//The Movie', '009 Re:Cyborg', '5 Centimeters Per Second']
#   comedy drama          (104 movies)  e.g. ['A Day to Remember', 'A Great Wall', "A Soldier's Plaything"]
#   suspense              (104 movies)  e.g. ['Albino Alligator', 'Anita', 'Bad Company']
#   romantic drama        (103 movies)  e.g. ['180', '3', '9 Songs']
#   drama, romance        (94 movies)  e.g. ['Aadmi Khilona Hai', 'Ahista Ahista', 'Ajantha (അജന്ത)']
#   animated short        (91 movies)  e.g. ['A Feather in His Hare', 'A Matter of Loaf and Death', 'A Wild Hare']
#   social                (83 movies)  e.g. ['1947 Earth', 'Aap Ki Marzi', 'Aarakshan']
#   action thriller       (79 movies)  e.g. ['8 x 10 Tasveer', 'Aadhavan', 'Abduction']
#   historical            (77 movies)  e.g. ['Agni Varsha', 'Alfred the Great', 'America']
#   documentary           (73 movies)  e.g. ['10 MPH', '51 Birch Street', 'A Complete History of My Sexual Failures']
#   serial                (71 movies)  e.g. ['Adventures of Captain Marvel', 'Adventures of Sir Galahad', 'Adventures of the Flying Cadets']
#   world war ii          (70 movies)  e.g. ['49th Parallel', 'A Canterbury Tale', 'A Matter of Life and Death']
#   family drama          (66 movies)  e.g. ['A Family Secret (Le Secret de ma mère)', 'Aai Phirse Bahar', 'Aaj Aur Kal']
#   war drama             (65 movies)  e.g. ['36 Hours', 'A Bell for Adano', 'A Stranger in My Arms']
#   drama, crime          (64 movies)  e.g. ['A Perfect World', 'Accidents Will Happen', 'Angels with Dirty Faces']
#   comedy, romance       (63 movies)  e.g. ['Ajab Prem Ki Ghazab Kahani', 'And So They Were Married', 'Angrej']
#   comedy, musical       (63 movies)  e.g. ['A Damsel in Distress', 'A Night at the Opera', 'Artists and Models Abroad']
#   comedy/drama          (62 movies)  e.g. ['24 Hour Party People', '48 Shades', 'After Sex']
#   romance, drama        (58 movies)  e.g. ['A Moment in Time', 'Aap Mujhe Achche Lagne Lage', 'Aashiqui']
#   biopic                (57 movies)  e.g. ['8 Seconds', 'Anata wo Wasurenai', 'Becoming Jane']
#   crime thriller        (56 movies)  e.g. ['7th Day', '8 Thottakkal', 'Aarathu Sinam']
#   historical drama      (54 movies)  e.g. ['23rd March 1931: Shaheed', 'A Man for All Seasons', 'Admiral']
#   black comedy          (52 movies)  e.g. ['8 Heads in a Duffel Bag', "A Beginner's Guide to Endings", 'A Day in the Death of Joe Egg']
#   action comedy         (51 movies)  e.g. ['2 Guns', '21 Jump Street', '22 Jump Street']
#   comedy short          (50 movies)  e.g. ['A Ducking They Did Go', 'A Gem of a Jam', "All the World's a Stooge"]
#   superhero             (48 movies)  e.g. ['Amazing Spider-Man, TheThe Amazing Spider-Man', 'Avengers, TheThe Avengers', 'Batman Begins']
#   crime comedy          (47 movies)  e.g. ['48 Hrs.', 'A Nice Little Bank That Should Be Robbed', 'A Nightingale Sang in Berkeley Square']
#   horror comedy         (47 movies)  e.g. ['Abbott and Costello Meet the Mummy', 'Ammo Bomma', 'Anando Brahma']
#   action, romance       (47 movies)  e.g. ['Adhinayakudu', 'Ami Shudhu Cheyechi Tomay', 'Awara']
#   drama, biography      (46 movies)  e.g. ['1492: Conquest of Paradise', 'Abe Lincoln in Illinois', 'Ali']
#   martial arts          (46 movies)  e.g. ['14 Blades', '18 Bronzemen', '2 Champions of Shaolin']
#   action, drama         (46 movies)  e.g. ['10,000 Hours', 'Aaj Ka Arjun', 'Awarapan']
#   drama, war            (44 movies)  e.g. ['A Farewell to Arms', 'Ace of Aces', 'All Quiet on the Western Front']
#   action, thriller      (43 movies)  e.g. ['9 KK Road', 'Aa Dekhen Zara', 'Action Khiladi']
#   romance/comedy        (41 movies)  e.g. ['Amit Sahni Ki List', 'Badrinath Ki Dulhania', 'Barfi!']
#   social drama          (40 movies)  e.g. ['Ab Dilli Dur Nahin', 'Achhut', 'Adalat']
#   melodrama             (39 movies)  e.g. ['A Child for Sale', 'A Woman of Affairs', 'All Mine to Give']
#   drama, adventure      (39 movies)  e.g. ['Air Mail', 'Barbary Coast', 'Captains Courageous']
#   action, comedy        (38 movies)  e.g. ['All About the Benjamins', 'Awara Paagal Deewana', 'Baadshah']
#   romance/drama         (38 movies)  e.g. ['A Town Like Alice', 'Anand', 'Ard al-Salam (Land of Peace)']
#   biography, drama      (37 movies)  e.g. ['127 Hours', 'A Beautiful Mind', 'All Eyez on Me']
#   drama, thriller       (36 movies)  e.g. ['2:22', "5150 Elm's Way", 'A Cure for Wellness']
#   drama, musical        (36 movies)  e.g. ['8 Mile', 'Bloodhounds of Broadway', 'Bottoms Up']
#   action drama          (36 movies)  e.g. ['Achamindri', 'Azaad', 'Bullies']
#   drama, family         (36 movies)  e.g. ['Aakhir Kyon?', 'Aap Ke Saath', 'Agar Tum Na Hote']
#   comedy, family        (35 movies)  e.g. ['102 Dalmatians', 'Best Actor', 'Big Fat Liar']
#   comedy, crime         (31 movies)  e.g. ['2 Days in the Valley', 'A Slight Case of Murder', 'Avenging Angelo Baby Beethoven Baby Newton']
#   mockumentary          (31 movies)  e.g. ['A Mighty Wind', 'A Short Film About John Bolton', 'Behind the Mask: The Rise of Leslie Vernon']
#   short                 (30 movies)  e.g. ['A Bird in the Head', "A Day's Pleasure", "Antonio's Breakfast"]
#   drama / romance       (30 movies)  e.g. ['9 Nelalu', 'A Moment of Love', 'Amrithadhare']
#   comedy / romance      (30 movies)  e.g. ['Book of Love', 'Breakup Buddies', 'Bride Wars']
#   romance, comedy       (29 movies)  e.g. ['Da Thadiya (ഡാ തടിയാ)', 'Deewana Mastana', 'Dil Maange More']
#   romance drama         (28 movies)  e.g. ['A Woman of Paris', 'Aar Paar', 'Amber']
#                         (28 movies)  e.g. ['Aanch', 'Aman Ke Farishtey', 'Chota Jadugar']
#   tokusatsu             (28 movies)  e.g. ['Attack on Titan', 'Attack on Titan: End of the World', 'Cho Kamen Rider Den-O & Decade Neo Generations: The Onigashima Warship']
#   spy                   (27 movies)  e.g. ['13 Rue Madeleine', 'A Yank in Libya', 'Above Suspicion']
#   action, crime, drama  (27 movies)  e.g. ['Aaj Ka Daur', 'Agneekaal', 'Avinash']
#   animated film         (25 movies)  e.g. ['9', 'A Boy Named Charlie Brown', 'All Dogs Go to Heaven']
#   drama, comedy         (24 movies)  e.g. ['A Stranger in Town', 'Bachchan', 'Being Cyrus']
#   dramedy               (24 movies)  e.g. ['Admission', 'Damsels in Distress', 'Demolition']
#   sports                (23 movies)  e.g. ['1983', 'Chak De India', 'Crazylegs']
#   drama, mystery        (22 movies)  e.g. ['A Face in the Fog', 'Atlas Shrugged: Part II', "Charlie Chan's Chance"]
#   psychological thriller  (22 movies)  e.g. ['18 Vayasu', '404', 'Adavadi']
#   mythology             (22 movies)  e.g. ['Bhakta Raghunath', 'Bhookailas', 'Chandrahasa']
#   drama, action         (21 movies)  e.g. ['1909', 'Air Hawks', 'Belli']
#   biographical          (20 movies)  e.g. ['Balgandharva', 'Buddha', 'Daniel Boone']
#   comedy, fantasy       (20 movies)  e.g. ["A Midsummer Night's Dream", 'Babes in Toyland', 'Beetlejuice']
#   sports drama          (20 movies)  e.g. ['Bhooloham', 'He Got Game', 'Hoosiers']
#   family, fantasy       (20 movies)  e.g. ['Alice in Wonderland', 'Bedtime Stories', 'Bridge to Terabithia']
#   action, sci-fi        (20 movies)  e.g. ['After Earth', 'Alien Hunter', 'Digimon Adventure tri. Part 1: Reunion']
#   action / drama        (20 movies)  e.g. ['Aagadu', 'Arjun (2011 film)', 'Backroads']
#   literary drama        (20 movies)  e.g. ['A Month in the Country', 'A Tale of Two Cities', 'Anna Karenina']
#   drama, sports         (19 movies)  e.g. ['A Million to One', 'Against the Ropes', 'Any Given Sunday']
#   comedy, horror        (19 movies)  e.g. ['100 Bloody Acres', 'Abbott and Costello Meet Frankenstein', 'Abbott and Costello Meet the Killer, Boris Karloff']
#   short subject         (19 movies)  e.g. ['12:01 PM', 'Dunked in the Deep', 'Elevated']
#   romantic thriller     (19 movies)  e.g. ['Anegan', 'Ayalum Njanum Thammil (അയാളും ഞാനും തമ്മിൽ)', 'Azhagiya Tamil Magan']
#   spy/action            (19 movies)  e.g. ['Diamonds Are Forever', 'Die Another Day', 'Dr. No']
#   political thriller    (18 movies)  e.g. ['Autonagar Surya', 'Breach', 'Company You Keep, TheThe Company You Keep']
#   romance / drama       (18 movies)  e.g. ['A Beautiful Life', 'Amphetamine', 'Anniversary']
#   comedy, mystery       (17 movies)  e.g. ['After the Thin Man', 'Bulldog Drummond Strikes Back', 'Charlie Chan at the Circus']
#   horror, thriller      (17 movies)  e.g. ['Aadupuliyattam', 'Abraham Lincoln: Vampire Hunter', 'Akalpith']
#   folklore              (17 movies)  e.g. ['Aggi Ramudu', 'Alibabavum 40 Dongalu', 'Allauddin Adhbhuta Deepam']
#   crime, drama          (16 movies)  e.g. ['Ardh Satya', 'Detroit', 'Elephant']
#   costume drama         (16 movies)  e.g. ['Al Hilal a.k.a. Judgemnt Of Allah', 'Baaz', 'Chandirani']
#   docudrama             (16 movies)  e.g. ['A Cry in the Dark', 'A Scream from Silence (Mourir à tue-tête)', 'A War Story']
#   family, drama         (16 movies)  e.g. ['Andre', 'Avtaar', 'Ek Hi Bhool']
#   action, crime         (16 movies)  e.g. ['15 Minutes', '2 Fast 2 Furious', '3000 Miles to Graceland']
#   horror thriller       (16 movies)  e.g. ['11-11-11', 'Cabin in the Woods, TheThe Cabin in the Woods', 'Cloth, TheThe Cloth']
#   comedy/crime          (16 movies)  e.g. ['Buster', 'Coffee with D', 'Crackerjack']
#   crime/drama           (16 movies)  e.g. ['A Death in the Gunj', 'Chicago Joe and the Showgirl', 'Daddy']
#   action/drama          (16 movies)  e.g. ['Agneepath', 'Bhoomi', 'D Day']
#   masala                (16 movies)  e.g. ['Anbanavan Asaradhavan Adangadhavan', 'Balupu', 'Boss']
#   western comedy        (15 movies)  e.g. ['4 for Texas', 'A Ticket to Tomahawk', 'Alias Jesse James']
#   science-fiction       (15 movies)  e.g. ['Black Hunters', 'Blade Runner', 'Cypher']
#   comedy / drama        (15 movies)  e.g. ['72 Tenants of Prosperity', 'A Family Affair', 'Al-halfout (The Vile)']
#   drama, horror         (14 movies)  e.g. ['Battery, TheThe Battery', 'Behind the Mask', 'Black Moon']
#   action adventure      (14 movies)  e.g. ['20,000 Leagues Under the Sea', 'Amar Jyoti', 'Captain Fury']
#   war, drama            (14 movies)  e.g. ['A Midnight Clear', 'Ab Tumhare Hawale Watan Saathiyo', 'Allegiance']
#   rom com               (14 movies)  e.g. ["'Til There Was You", 'Bahuparak', 'Fools Rush In']
#   animated feature      (14 movies)  e.g. ['April and the Extraordinary World', 'Babar: King of the Elephants', 'Babar: The Movie']
#   comedy, action        (14 movies)  e.g. ['Adhurs', 'All for the Winner', 'Batman']
#   animated, family      (14 movies)  e.g. ['Despicable Me', 'Despicable Me 2', "Dr. Seuss' The Lorax"]
#   family film           (14 movies)  e.g. ['Air Bud', 'Air Bud: Golden Receiver', 'Beverly Hills Chihuahua 3: Viva la Fiesta!']
#   action / comedy       (14 movies)  e.g. ['Cicak Man 3', 'Come Fly the Dragon', 'Dongodu']
#   action/thriller       (14 movies)  e.g. ['Aazaan', 'Crash Landing', 'Don 2: The Chase Continues']
#   social family drama   (14 movies)  e.g. ['Anpadh', 'Aurat', 'Bhabhi']
#   propaganda            (13 movies)  e.g. ['Combat America', "Don't Be a Sucker", 'Duck and Cover']
#   horror, comedy        (13 movies)  e.g. ['An American Werewolf in London', 'Bulong', "Cat's Eye"]
#   musical drama         (13 movies)  e.g. ['Black Nativity', 'Can a Song Save Your Life?', 'Inside Llewyn Davis']
#   action, science fiction  (13 movies)  e.g. ['Barb Wire', 'Battle: Los Angeles', 'Battleship']
#   action/comedy         (13 movies)  e.g. ['Aa Gaya Hero', 'Bbuddah... Hoga Terra Baap', 'Dabangg 2']
#   sex comedy            (13 movies)  e.g. ['Au Pair Girls', 'Commuter Husbands', 'Confessions of a Driving Instructor']
#   action / crime        (13 movies)  e.g. ['Cold War', 'Dealer/Healer', 'Firestorm']
#   kaiju                 (13 movies)  e.g. ['Gamera the Brave', 'Godzilla Against Mechagodzilla', 'Godzilla Raids Again']
#   western, comedy       (12 movies)  e.g. ['A Big Hand for the Little Lady', 'A Talent for Loving', "Buffalo Bill and the Indians, or Sitting Bull's History Lesson"]
#   slapstick             (12 movies)  e.g. ['A Merry Mix Up', 'Fifi Blows Her Top', 'Flying Saucer Daffy']
#   sci-fi comedy         (12 movies)  e.g. ['Amanda and the Alien', 'Attack of the 60 Foot Centerfold', 'Gremlins 2: The New Batch']
#   comedy horror         (12 movies)  e.g. ['Cut', 'Horrorween', 'Intlo Deyyam Nakem Bhayam']
#   slasher               (12 movies)  e.g. ["A Nightmare on Elm Street 2: Freddy's Revenge", 'A Nightmare on Elm Street 3: Dream Warriors', 'Alone in the Dark']
#   crime, comedy         (12 movies)  e.g. ['Cookie', 'Cops and Robbers', "Dead Man's Bluff"]
#   comedy, thriller      (12 movies)  e.g. ['After Hours', 'American Psycho', 'Bad Kids Go to Hell']
#   comedy, drama, romance  (12 movies)  e.g. ['Bachna Ae Haseeno', 'Bombay to Bangkok', 'Chameli Ki Shaadi']
#   comedy/romance        (12 movies)  e.g. ['Bareilly Ki Barfi', 'For Better, for Worse', 'Jagga Jasoos']
#   crime/thriller        (12 movies)  e.g. ['Buno Haansh', 'Crossroads to Crime', 'Drohi']
#   drama/comedy          (12 movies)  e.g. ["Buddy's Song", 'Catch Us If You Can', 'Ermo']
#   action/romance        (12 movies)  e.g. ['A Gentleman', 'Commando-A One Man Army', 'Force']
#   devotional            (12 movies)  e.g. ['Bhakta Vidur', 'Chakradhari', 'Chandrasena']
#   period drama          (11 movies)  e.g. ['Begum Jaan', 'Cousin Bette', 'Cracks']
#   mystery, thriller     (11 movies)  e.g. ['Angels', 'Arikil Oraal', 'Asambhav']
#   screwball comedy      (11 movies)  e.g. ['Arsenic and Old Lace', 'Christmas in July', 'His Girl Friday']
#   disaster film         (11 movies)  e.g. ['Arctic Blast', 'City on Fire', "Dante's Peak"]
#   comedy, sports        (11 movies)  e.g. ['Angels in the Outfield', 'Balls of Fury', 'Blades of Glory']
#   action, horror        (11 movies)  e.g. ['Aliens vs. Predator: Requiem', 'Bees Saal Baad', 'Blade II']
#   romantic-comedy       (11 movies)  e.g. ["All's Well, Ends Well 2011", 'Aloha', 'Barefoot']
#   action, crime, drama, romance  (11 movies)  e.g. ['Aadmi', 'Bandish', 'Diljalaa']
#   drama, social         (11 movies)  e.g. ['Astitva', 'Banaras: A Mystic Love Story', 'Chingaari']
#   action masala         (11 movies)  e.g. ['Aambala', 'Bairavaa', 'Kaththi Sandai']
#   epic                  (10 movies)  e.g. ['Ben-Hur: A Tale of the Christ', 'Birth of a Nation', 'Cleopatra']
#   swashbuckler          (10 movies)  e.g. ['Beau Geste', 'Crossed Swords', 'Don Q, Son of Zorro']
#   war comedy            (10 movies)  e.g. ['Follow the Boys', 'Good Morning, Vietnam', 'Imitation General']
#   disaster              (10 movies)  e.g. ['2012', 'Daylight', 'Deep Impact']
#   comedy, science fiction  (10 movies)  e.g. ['Alien Trespass', 'Back to the Future Part III', 'Ghostbusters II']
#   comedy/action         (10 movies)  e.g. ['Abhinay Chakra', 'Bol Bachchan', 'Chennai Express']
#   musical, comedy       (9 movies)  e.g. ['Emo the Musical', 'High Society Blues', 'In Caliente']
#   adventure, fantasy    (9 movies)  e.g. ['Hobbit: The Desolation of Smaug, TheThe Hobbit: The Desolation of Smaug', 'Lost Horizon', 'Oz the Great and Powerful']
#   comedy thriller       (9 movies)  e.g. ['Blondes for Danger', 'Boys of the City', 'Double Barrel']
#   political drama       (9 movies)  e.g. ['Ada', 'December-1', 'Fame Is the Spur']
#   adventure, family     (9 movies)  e.g. ['Cloak & Dagger', 'Free Willy 2: The Adventure Home', 'Goonies, The']
#   action-adventure, fantasy  (9 movies)  e.g. ['Clash of the Titans', 'Conan the Barbarian', 'Harry Potter and the Deathly Hallows: Part 1']
#   musical/comedy        (9 movies)  e.g. ['A Date with a Dream', "A Hard Day's Night", 'Bees in Paradise']
#   romance/thriller      (9 movies)  e.g. ['Bloody Isshq', 'Chirodini Tumi Je Amar 2', 'Dangerous Ishq']
#   national film board animated short  (9 movies)  e.g. ['Black Soul', "Bob's Birthday", 'Dimanche/Sunday']
#   wuxia                 (9 movies)  e.g. ['Ashes of Time Redux', 'Come Drink with Me', 'Fearless']
#   action / romance      (9 movies)  e.g. ['Adavi Ramudu', 'Balu', 'Dil']
#   horror, romance, comedy  (9 movies)  e.g. ['Troublesome Night 13', 'Troublesome Night 14', 'Troublesome Night 15']
#   thriller drama        (9 movies)  e.g. ['Kurangu Bommai', 'Lens', 'Nirnnayakam']
#   comedy, western       (8 movies)  e.g. ['Big Money Rustlas', 'Chimmie Fadden Out West', 'Dangerous Nan McGrew']
#   drama, western        (8 movies)  e.g. ['Annie Oakley', 'Cimarron', 'Dances with Wolves']
#   adventure, drama      (8 movies)  e.g. ['High Gear', 'Hugo', 'Into the Wild']
#   mystery, comedy       (8 movies)  e.g. ['All Through the Night', 'Charlie Chan in Egypt', 'Charlie Chan in Paris']
#   exploitation          (8 movies)  e.g. ['Chained for Life', 'Delinquent Daughters', 'Let Me Die a Woman']
#   spy thriller          (8 movies)  e.g. ['Foreign Correspondent', 'Funeral In Berlin', 'Journey into Fear']
#   biography, crime      (8 movies)  e.g. ['Baby Face Nelson', 'Capote', 'Dillinger']
#   sexploitation         (8 movies)  e.g. ['Bad Girls Go to Hell', 'Faster, Pussycat! Kill! Kill!', 'Girls in Prison']
#   comedy, parody        (8 movies)  e.g. ['30 Nights of Paranormal Activity with the Devil Inside the Girl with the Dragon Tattoo', 'Amazon Women on the Moon', 'American Dreamz']
#   animation, family     (8 movies)  e.g. ['Brother Bear', 'Finding Nemo', "Heidi's Song"]
#   action, fantasy       (8 movies)  e.g. ['47 Ronin', 'Conan the Destroyer', 'Dragonball Evolution']
#   parody                (8 movies)  e.g. ['Breaking Wind', 'Epic Movie', "Jane Austen's Mafia!"]
#   comedy, teen          (8 movies)  e.g. ['17 Again', 'College', 'Easy A']
#   crime, thriller       (8 movies)  e.g. ['Along Came a Spider', 'Cellular', 'City of God']
#   satire                (8 movies)  e.g. ['Bamboozled', 'Doordarshan Eti Jantra', 'Jackboots on Whitehall']
#   action-comedy         (8 movies)  e.g. ['Bandipotu', 'Central Intelligence', 'Keanu']
#   dark comedy           (8 movies)  e.g. ['August: Osage County', 'How I Won the War', 'Lucky']
#   supernatural horror   (8 movies)  e.g. ['Conjuring, TheThe Conjuring', 'Night Terrors', 'Paranormal Activity 3']
#   thriller, drama       (8 movies)  e.g. ['Agni Sakshi', "Donovan's Echo", 'Ek Hasina Thi']
#   romance / comedy      (8 movies)  e.g. ['A Wedding Invitation', 'Kotha Janta', 'Love in Space']
#   drama / action        (8 movies)  e.g. ['Anak Halal', 'Annayya', 'Brothers']
#   comedy / action       (8 movies)  e.g. ['Abang Long Fadil', 'Cicakman 2: Planet Hitam', 'From Vegas to Macau']
#   suspense thriller     (8 movies)  e.g. ['Beautiful', 'Dongala Mutha', 'Kanal']
#   short film            (7 movies)  e.g. ['Aruba', 'Blood Brothers', 'Hag in a Black Leather Jacket']
#   fantasy drama         (7 movies)  e.g. ['Cinderella', "Dante's Inferno", 'Devta']
#   detective             (7 movies)  e.g. ['Arjun — Kalimpong E Sitaharan', 'Girl in the Headlines', 'Goyenda Gogol']
#   spy drama             (7 movies)  e.g. ['Assignment - Paris!', 'British Agent', 'Espionage Agent']
#   romantic              (7 movies)  e.g. ['Bird of Paradise', 'From Sydney with Love', 'Kayal']
#   bio-pic               (7 movies)  e.g. ['Gentleman Jim', 'Jack London', 'Juarez']
#   western, biography    (7 movies)  e.g. ['Buffalo Bill', 'Pat Garrett and Billy the Kid', 'The Left Handed Gun']
#   musical, drama        (7 movies)  e.g. ['A Star is Born', 'Disco Dancer', 'Goodbye, Mr. Chips']
#   spy film              (7 movies)  e.g. ['5 Steps to Danger', 'A Man Could Get Killed', 'Agent for H.A.R.M.']
#   adult                 (7 movies)  e.g. ['Behind the Green Door', 'Deep Throat', 'Forced Entry']
#   anthology             (7 movies)  e.g. ['Aana Mayil Ottakam', 'Bench Talkies - The First Bench', 'Chandamama Kathalu']
#   crime, action         (7 movies)  e.g. ['A Better Tomorrow 2', 'Breaking News', 'Daagdi Chaawl']
#   action, adventure     (7 movies)  e.g. ['Amanaat', 'G.I. Joe: The Rise of Cobra', 'Superman II']
#   action, family        (7 movies)  e.g. ['3 Ninjas Kick Back', 'Agent Cody Banks', 'Chekavar ( ചേകവർ )']
#   children's film       (7 movies)  e.g. ["George's Island", 'Paddington', 'Philips and the Monkey Pen']
#   historical/drama      (7 movies)  e.g. ['A Dangerous Method', 'Aftershock', 'Madame Pompadour']
#   comedy/musical        (7 movies)  e.g. ['Dance Band', 'Follow a Star', 'I Adore You']
#   drama/thriller        (7 movies)  e.g. ['Blind Shaft', 'Cigarette Ki Tarah', 'Kahaani']
#   comedy/horror         (7 movies)  e.g. ['Blood and Donuts', 'Tales That Witness Madness', 'The Cottage']
#   drama/musical         (7 movies)  e.g. ['Krishna Prema', 'Little Voice', 'Malleshwari']
#   romantic, drama       (7 movies)  e.g. ['Amar Deep', 'Barcelona: A Love Untold', 'Doosra Aadmi']
#   children              (7 movies)  e.g. ['Chillar Party', 'Chintoo[12]', 'Gattu']
#   romance/action        (7 movies)  e.g. ['Andhrudu', 'Bodyguard', 'Ek Tha Tiger']
#   action, comedy, romance  (7 movies)  e.g. ['Daava', 'Dookudu', 'Herogiri']
#   religious             (7 movies)  e.g. ['Gopal Krishna', 'Hanuman Patal Vijay', 'Radha Krishna']
#   romance, thriller     (7 movies)  e.g. ['Aagathan ( ആഗതൻ)', 'Apoorvaragam ( അപൂർവരാഗം )', 'Dil Tera Deewana']
#   action, drama, family  (7 movies)  e.g. ['Abdullah', 'Charnon Ki Saugandh', 'Dharam Kanta']
#   action-masala         (7 movies)  e.g. ['Jilla', 'Murattu Kaalai', 'Poojai']
#   ero                   (7 movies)  e.g. ['Madame Aema 10', 'Madame Aema 11', 'Madame Aema 2']
#   fantasy, romance      (6 movies)  e.g. ['A Kiss for Cinderella', 'Always', 'Nagina']
#   comedy romance        (6 movies)  e.g. ['Bale Bale Magadivoy', 'Bewaqoof', 'Dilli Ka Thug']
#   sci-fi, horror        (6 movies)  e.g. ['Alien: Covenant', 'Bride of Frankenstein', 'Cube 2: Hypercube']
#   fantasy thriller      (6 movies)  e.g. ['Lost River', 'Man with Two Lives', 'Nagarahavu']
#   historical epic       (6 movies)  e.g. ['Androcles and the Lion', 'Curse of the Golden Flower', 'El Cid']
#   musical, biography    (6 movies)  e.g. ['Hans Christian Andersen', 'I Dream of Jeanie', 'Love Me or Leave Me']
#   comedy, biography     (6 movies)  e.g. ['Cool Runnings', 'Ed Wood', 'Great Balls of Fire!']
#   spy comedy            (6 movies)  e.g. ['A Man Called Dagger', 'Austin Powers: International Man of Mystery', 'Casino Royale']
#   sports comedy         (6 movies)  e.g. ['Everybody Wants Some!!', 'Geordie', 'Long Gone']
#   science fiction, thriller  (6 movies)  e.g. ['Babylon A.D.', 'Cloverfield', 'In Time']
#   musical, romance      (6 movies)  e.g. ['Aattakatha', 'Gudgudee', 'Honey']
#   animation, comedy     (6 movies)  e.g. ['Hoodwinked!', 'Madagascar', 'My Entire High School Sinking Into the Sea']
#   bio-pic, drama        (6 movies)  e.g. ['Behind the Candelabra', 'Jobs', 'Notorious']
#   horror, suspense      (6 movies)  e.g. ['Dalaw', 'Feng Shui 2', 'Segunda Mano']
#   romance, comedy, drama  (6 movies)  e.g. ['Bride for Rent', 'Cheeni Kum', 'It Takes a Man and a Woman']
#   world war i           (6 movies)  e.g. ['Aces High', 'Forever England', 'Mademoiselle from Armentieres']
#   african adventure     (6 movies)  e.g. ['Golden Ivory', 'Odongo', 'Safari']
#   spy/thriller          (6 movies)  e.g. ['A Dandy in Aspic', 'Operation Crossbow', 'The Ipcress File']
#   horror/comedy         (6 movies)  e.g. ['Freak Out', 'Kalpana', 'Mumsy, Nanny, Sonny and Girly']
#   drama / comedy        (6 movies)  e.g. ['A Gold Medal Winning Tramp Dog', 'Duckweed', 'One Night']
#   kung fu               (6 movies)  e.g. ['Bandits From Shantung', 'Half a Loaf of Kung Fu', 'Hand of Death']
#   martial arts / action  (6 movies)  e.g. ['Circus Kid', 'Iron Fisted Monk', 'Opium and the Kung-Fu Master']
#   love                  (6 movies)  e.g. ['Garam', 'Guntur Talkies', 'Krishna Gadi Veera Prema Gaadha']
#   fantasy anime         (6 movies)  e.g. ['Inuyasha the Movie: Affections Touching Across Time', 'Inuyasha the Movie: The Castle Beyond the Looking Glass', 'Naruto Shippūden 5: Blood Prison']
#   biographical drama    (5 movies)  e.g. ['Born to Be Blue', 'Home, Sweet Home', 'Iris']
#   comedy western        (5 movies)  e.g. ['Girl Rush', 'Rancho Deluxe', 'The Paleface']
#   biblical drama        (5 movies)  e.g. ['King of Kings', 'Samson and Delilah', 'Samson and Delilah']
#   operetta              (5 movies)  e.g. ['Golden Dawn', 'Song of the Flame', 'The Desert Song']
#   comedy mystery        (5 movies)  e.g. ['Fast and Furious', 'Fast and Loose', 'Lady of Burlesque']
#   romance musical       (5 movies)  e.g. ['April Fool', 'Basant Bahar', 'Dil Deke Dekho']
#   prison drama          (5 movies)  e.g. ['Inside (Histoire de pen)', 'Ladies They Talk About', 'Numbered Men']
#   horror, science fiction  (5 movies)  e.g. ['Apollo 18', 'C.H.U.D.', 'Dreamcatcher']
#   horror, sci-fi        (5 movies)  e.g. ['Alien vs. Predator', 'Dark Skies', 'Life']
#   crime, horror         (5 movies)  e.g. ['FeardotCom', 'Ichi the Killer', 'Murders in the Rue Morgue']
#   science fiction comedy  (5 movies)  e.g. ['Howard the Duck', 'Mars Attacks!', 'Space Truckers']
#   biography, musical    (5 movies)  e.g. ['Cadillac Records', 'Million Dollar Mermaid', 'The Benny Goodman Story']
#   biker film            (5 movies)  e.g. ['Chrome and Hot Leather', 'Hells Angels on Wheels', 'Naked Angels']
#   psychological horror  (5 movies)  e.g. ['Saw', 'Saw II', 'The Night God Screamed']
#   science fiction, comedy  (5 movies)  e.g. ['Back to the Future Part II', 'Evil Alien Conquerors', 'Galaxy Quest']
#   shakespearean         (5 movies)  e.g. ["A Midsummer Night's Dream", "Love's Labour's Lost", "Prospero's Books"]
#   war film              (5 movies)  e.g. ['A Very Long Engagement', 'Battle for Sevastopol', 'Burnt by the Sun 2']
#   family, musical       (5 movies)  e.g. ['Alvin and the Chipmunks', 'Alvin and the Chipmunks: The Squeakquel', 'August Rush']
#   fantasy romance       (5 movies)  e.g. ['Beastly', 'Beautiful Creatures', 'The Twilight Saga: Breaking Dawn - Part 1']
#   action-adventure      (5 movies)  e.g. ['Anaganaga Oka Raju', 'G.I. Joe: Retaliation', 'Robin Hood']
#   drama, romantic comedy  (5 movies)  e.g. ['Crazy Beautiful You', 'From Prada to Nada', 'Itazura na Kiss the Movie 2 ~Campus-Hen~']
#   supernatural thriller  (5 movies)  e.g. ['Apparition, TheThe Apparition', 'Bogan', 'Masss']
#   animated, comedy, family  (5 movies)  e.g. ['Cloudy with a Chance of Meatballs 2', 'Monsters University', 'Planes']
#   action-thriller       (5 movies)  e.g. ['Dark Truth, AA Dark Truth', 'Dohchay', 'Getaway']
#   horror / thriller     (5 movies)  e.g. ['Chaarulatha', 'Ice Cream', 'Mysterious Island']
#   war/drama             (5 movies)  e.g. ["Don't Cry, Nanking", 'Rangoon', 'Red Cherry']
#   drama/romance         (5 movies)  e.g. ['Bicycle Kick', 'Highway', 'I Give My Heart']
#   sports/comedy         (5 movies)  e.g. ['Cup-tie Honeymoon', 'Fever Pitch', 'Just My Luck']
#   coming-of-age drama   (5 movies)  e.g. ['Amy George', 'My Dog Vincent', 'Set Me Free (Emporte-moi)']
#   drama film            (5 movies)  e.g. ['Careful', 'Particle (film)', 'Soulless 2']
#   comedy film           (5 movies)  e.g. ['Ghost', 'Last Wedding', 'The Land of Oz']
#   drama/action          (5 movies)  e.g. ['Aurangzeb', 'Crouching Tiger, Hidden Dragon', 'Desi Kattey']
#   crime / thriller      (5 movies)  e.g. ['Cross', 'Helios', 'Overheard 2']
#   action / martial arts  (5 movies)  e.g. ['Ip Man: The Final Fight', 'My Father Is a Hero', 'Tai Chi Master']
#   drama / action / crime  (5 movies)  e.g. ['Drug War', 'Extraordinary Mission', 'Line Walker']
#   history               (5 movies)  e.g. ['Amara Shilpi Jakkanna', 'Asoka', 'Russian Ark']
#   comedy, drama, family  (5 movies)  e.g. ['Bhabhi', 'Khubsoorat', 'Man Pasand']
#   action, comedy, drama  (5 movies)  e.g. ['Chaand Kaa Tukdaa', 'Pardesi Babu', 'Pyari Behna']
#   action, comedy, crime, drama  (5 movies)  e.g. ['Andaz', 'Gopi Kishan', 'Hum Hain Kamaal Ke']
#   romance, action       (5 movies)  e.g. ['Jatt James Bond', 'Krishna', 'Mirchi']
#   thriller, romance     (5 movies)  e.g. ['Gunaah', 'I Love Me', 'Kurbaan']
#   political             (5 movies)  e.g. ['Firaaq', 'Leader', 'Left Right Left']
#   thriller/drama        (5 movies)  e.g. ['Calapor', 'Dear Maya', 'Irada']
#   horror / comedy       (5 movies)  e.g. ['Geethanjali', 'Kala Malam Bulan Mengambang', 'Pontianak Menjerit']
#   tokusatsu, action, sci-fi  (5 movies)  e.g. ['Kamen Rider Ex-Aid the Movie: True Ending', "Kamen Rider Ghost: The 100 Eyecons and Ghost's Fated Moment", 'Kamen Rider Heisei Generations Final: Build & Ex-Aid with Legend Rider']
#   adventure serial      (4 movies)  e.g. ['King of the Royal Mounted', 'The Perils of Pauline', 'The Purple Monster Strikes']
#   short comedy          (4 movies)  e.g. ['Fatty and Mabel Adrift', 'Lonesome Luke Leans to the Literary', 'One A.M.']
#   comedy, adventure     (4 movies)  e.g. ['Riding on Air', 'The Circus', 'The Gold Rush']
#   fantasy, adventure    (4 movies)  e.g. ['Alibaba', 'Princess Mononoke', 'The Lost World']
#   dramatic comedy       (4 movies)  e.g. ['A Room for Romeo Brass', 'Meet John Doe', 'Smashed']
#   science fiction, horror  (4 movies)  e.g. ['Destroy All Monsters', 'Hollow Man', 'The Invisible Man']
#   mystery, horror       (4 movies)  e.g. ['Condemned to Live', 'Mark of the Vampire', 'The Ghost Walks']
#   drama, science fiction  (4 movies)  e.g. ['Eternal Sunshine of the Spotless Mind', 'Last War !The Last War', 'Life Returns']
#   drama, fantasy        (4 movies)  e.g. ['A Christmas Carol', 'Beasts of the Southern Wild', 'Field of Dreams']
#   gangster              (4 movies)  e.g. ['Each Dawn I Die', 'Pattiyal', 'Pudhupettai']
#   biblical              (4 movies)  e.g. ['Esther and the King', 'Noah', 'The Great Commandment']
#   war, biography        (4 movies)  e.g. ['Bat*21', 'MacArthur', 'Patton']
#   experimental          (4 movies)  e.g. ['Dreams That Money Can Buy', 'Mishima: A Life in Four Chapters', 'Slacker']
#   espionage             (4 movies)  e.g. ['Hotel Reserve', 'Master Spy', 'Tokyo File 212']
#   biography, war        (4 movies)  e.g. ['Che', 'Lion of the Desert', 'Megan Leavey']
#   comedy, satire        (4 movies)  e.g. ['Canadian Bacon', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'Poshter Girl']
#   neo-noir              (4 movies)  e.g. ['Devil in a Blue Dress', 'Gurgaon', 'The Naked Kiss']
#   sci-fi, comedy        (4 movies)  e.g. ['Colossal', 'Creator', "Now You See Him, Now You Don't"]
#   sci-fi horror         (4 movies)  e.g. ['Embryo', 'Grave Encounters', 'Predators']
#   fantasy, thriller     (4 movies)  e.g. ['ESPY', 'Gayab', 'The Hole']
#   erotic thriller       (4 movies)  e.g. ['Basic Instinct', 'Call Me', 'Canyons, TheThe Canyons']
#   rom-com               (4 movies)  e.g. ['Aiyyaa', 'Housesitter', 'Ramaiya Vastavaiya']
#   teen comedy           (4 movies)  e.g. ['Citizen Duane', 'P.U.N.K.S.', "Porky's"]
#   comedy-drama, romance  (4 movies)  e.g. ['Cosmopolitan', 'Flirt', 'Silver Linings Playbook']
#   dance                 (4 movies)  e.g. ['Boogie Town', 'Step Up', 'Step Up 2: The Streets']
#   action, crime drama   (4 movies)  e.g. ['Armored', 'Gangster Squad', 'Takers']
#   adventure, comedy     (4 movies)  e.g. ['30 Minutes or Less', 'The Imaginarium of Doctor Parnassus', 'What the Jatt!!']
#   family, live-action   (4 movies)  e.g. ['Alvin and the Chipmunks: Chipwrecked', 'Marmaduke', 'The Smurfs']
#   biographical, drama   (4 movies)  e.g. ['Breathe', 'Goodbye Christopher Robin', 'Lovelace']
#   christian             (4 movies)  e.g. ["God's Not Dead", 'Heaven Is for Real', 'Saving Christmas']
#   crime, drama, thriller  (4 movies)  e.g. ['Amanush 2', 'Khal-Naaikaa', 'Locust']
#   thriller, action      (4 movies)  e.g. ['Aankhen', 'Dhoom', 'First Kill']
#   comedy / horror       (4 movies)  e.g. ['Howling III', 'Mayangaathey', 'The Cars That Ate Paris']
#   action / adventure    (4 movies)  e.g. ['Beach Spike', 'CZ12', 'Mad Max']
#   action romance        (4 movies)  e.g. ['Macho Mustanaa', 'Rocket', 'Shikari']
#   romance action        (4 movies)  e.g. ['Badsha The Don', 'Balakrishnudu', 'Bhale Manchi Roju']
#   comedy/thriller       (4 movies)  e.g. ['A Man Could Get Killed', 'Ghanchakkar', 'Mickey Virus']
#   world war ii/drama    (4 movies)  e.g. ['Johnny Frenchman', 'The Captive Heart', 'The Way to the Stars']
#   short drama           (4 movies)  e.g. ['Curtains', "Rock 'n' Roll Nightmare", 'The Dead Father']
#   world war ii/pow      (4 movies)  e.g. ['Albert R.N.', 'Merry Christmas, Mr. Lawrence', 'The Bridge on the River Kwai']
#   world war ii comedy   (4 movies)  e.g. ['Operation Bullshine', 'Soft Beds, Hard Battles', 'The Square Peg']
#   drama/biographical    (4 movies)  e.g. ['An Englishman in New York', 'Creation', 'Little Ashes']
#   slasher film          (4 movies)  e.g. ['Dream Home', 'Happy Birthday to Me', 'My Bloody Valentine']
#   national film board documentary  (4 movies)  e.g. ['Being Caribou', 'Four Women of Egypt', 'Stories We Tell']
#   action/adventure      (4 movies)  e.g. ['Dr. Wai in "The Scripture with No Words"', 'In the Name of the King 3: The Last Mission', 'Sholay 3D']
#   suspense / thriller   (4 movies)  e.g. ['I.C. Kill', 'Inside the Girls', 'The Great Wall']
#   action / thriller     (4 movies)  e.g. ['KL Special Force', 'Karthikeya', 'Kung Fu Jungle']
#   drama / crime         (4 movies)  e.g. ['Al-Yateematain (The Two Orphans)', 'Kursi al-I`tiraf (Chair of Confession)', 'Red Amnesia']
#   comedy / fantasy      (4 movies)  e.g. ['Meow', 'Monster Hunt', 'The Eight Hilarious Gods']
#   sword                 (4 movies)  e.g. ['The Blade Spares None', 'The Chase', 'The Crimson Charm']
#   action / kung fu / comedy  (4 movies)  e.g. ['By Hook or by Crook', 'Drunken Master', 'Sleeping Fist']
#   action / martial arts / comedy  (4 movies)  e.g. ['Carry On Pickpocket', 'Fong Sai-yuk II', 'High Risk']
#   romance, comedy, horror  (4 movies)  e.g. ['Troublesome Night 10', 'Troublesome Night 11', 'Troublesome Night 12']
#   horror, drama         (4 movies)  e.g. ['Aptharakshaka', 'Maria Leonora Teresa', 'Pagpag: Siyam na Buhay']
#   romance / action      (4 movies)  e.g. ['Gunturodu', 'Love', 'Power']
#   costume               (4 movies)  e.g. ['Alam Ara', 'Amrit Manthan', 'Aurat']
#   thriller, mystery     (4 movies)  e.g. ['36 China Town', 'Grandmaster', 'Gumnaam – The Mystery']
#   action, crime, drama, thriller  (4 movies)  e.g. ['Aakrosh', 'Khazana', 'Muqabla']
#   action, drama, romance  (4 movies)  e.g. ['Commando', 'Dum', 'Lakeer - Forbidden Lines']
#   suspense, thriller    (4 movies)  e.g. ['Janakan ( ജനകൻ)', 'Passenger', 'Shikkar ( ശിക്കാർ )']
#   drama, romance, thriller  (4 movies)  e.g. ['Aitraaz', 'Fida', 'Jism']
#   adult comedy          (4 movies)  e.g. ['Anubhava (Re-release)', 'Grand Masti', 'Trisha Illana Nayanthara']
#   satirical comedy      (4 movies)  e.g. ['Breaking News', 'Gopala Gopala', 'Mata']
#   satire, drama         (4 movies)  e.g. ['Bhakthajanangalude Sradhakku (ഭക്തജനങ്ങളുടെ ശ്രദ്ധയ്ക്ക്)', 'Bhoopadathil Illatha Oridam (ഭൂപടത്തിൽ ഇല്ലാത്ത ഒരിടം)', 'God for Sale']
#   comedy-thriller       (4 movies)  e.g. ['Biriyani', 'Lacchimdeviki O Lekkundi', 'Soodhu Kavvum']
#   supernatural          (4 movies)  e.g. ['Assassination Classroom', 'K: Missing Kings', 'Kaashmora']
#   socio-fantasy         (4 movies)  e.g. ['Daruvu', 'Dhamarukam', 'Eega']
#   samurai film          (4 movies)  e.g. ['Miyamoto Musashi', 'Samurai II: Duel at Ichijoji Temple', 'Seven Samurai']
#   pink                  (4 movies)  e.g. ['A Saloon Wet with Beautiful Women', 'Daydream', 'The Glamorous Life of Sachiko Hanai']
#   yakuza                (4 movies)  e.g. ['Beyond Outrage', 'Cops vs. Thugs', 'Graveyard of Honor']
#   science fiction anime  (4 movies)  e.g. ['Metropolis', 'Paprika', 'Tekkon Kinkreet']
#   drama, romance, slice of life  (4 movies)  e.g. ['Her Love Boils Bathwater', 'P and JK', 'Suki ni Naru Sono Shunkan o']
#   western drama         (3 movies)  e.g. ['Open Range', 'The Aryan', 'The Missing']
#   drama romance         (3 movies)  e.g. ['Band Baaja Baaraat', 'Blind Husbands', 'Jassy']
#   comedy, drama, musical  (3 movies)  e.g. ['Fashions of 1934', 'Operator 13', 'Pyaar Ki Jeet']
#   western, musical      (3 movies)  e.g. ['High, Wide and Handsome', 'Rose Marie', 'The Big Show']
#   drama, music          (3 movies)  e.g. ['Beat Street', 'Kamagni', 'Mad About Music']
#   adventure drama       (3 movies)  e.g. ["Striker's Mountain", 'The High Bright Sun', 'The Real Glory']
#   musical fantasy       (3 movies)  e.g. ['Princess Raccoon', 'The 5,000 Fingers of Dr. T', 'The Wizard of Oz']
#   animated comedy       (3 movies)  e.g. ['Chicken Run', 'My Favorite Duck', 'Pixels']
#   romantic fantasy      (3 movies)  e.g. ['A Guy Named Joe', 'Charlie St. Cloud', 'Katari Veera Surasundarangi (3D)']
#   horror, musical       (3 movies)  e.g. ['Happiness of the Katakuris !The Happiness of the Katakuris', 'Phantom of the Opera', 'Repo! The Genetic Opera']
#   romantic musical      (3 movies)  e.g. ['Atlantic City', 'Kashmir Ki Kali', 'Ormayundo Ee Mukham']
#   fantasy, comedy       (3 movies)  e.g. ["For Heaven's Sake", 'Harvey', 'It Happened Tomorrow']
#   educational           (3 movies)  e.g. ['Bob and Sally', 'Dinosaurs! – A Fun-Filled Trip Back in Time!', 'One Got Fat']
#   drama, epic           (3 movies)  e.g. ['Ben-Hur', 'Doctor Zhivago', 'Rosario (2010 film)']
#   family comedy         (3 movies)  e.g. ["Bailey's Billion$", 'Honey, I Shrunk the Kids', 'Pollyanna']
#   family, comedy        (3 movies)  e.g. ['Camp Nowhere', 'Sakudumbam Shyamala ( സകുടുംബം ശ്യാമള )', 'That Darn Cat!']
#   spy film, comedy      (3 movies)  e.g. ["Murderers' Row", 'Our Man Flint', 'The Silencers']
#   true crime            (3 movies)  e.g. ['The Boston Strangler', 'The Pursuit of D. B. Cooper', 'Untold Story']
#   biography, sports     (3 movies)  e.g. ['Bobby Jones: Stroke of Genius', 'Paper Lion', 'The Express']
#   war, comedy           (3 movies)  e.g. ['Buffalo Soldiers', 'Catch-22', 'Three Kings']
#   war, action           (3 movies)  e.g. ['Cross of Iron', "Kelly's Heroes", 'Red Scorpion']
#   adult film            (3 movies)  e.g. ['Maraschino Cherry', 'Naked Came The Stranger', 'The Opening of Misty Beethoven']
#   sci-fi drama          (3 movies)  e.g. ['Darwin', 'The Last Chase', 'Time After Time']
#   action, war           (3 movies)  e.g. ['Red Dawn', 'The Sea Wolves', 'Uncommon Valor']
#   science fiction, drama  (3 movies)  e.g. ['Monsters', 'The Abyss', "The Handmaid's Tale"]
#   animated, comedy      (3 movies)  e.g. ['Aladdin', 'Hotel Transylvania', "Jay & Silent Bob's Super Groovy Cartoon Movie"]
#   romance, war          (3 movies)  e.g. ['71 er Shongram', 'Beyond Borders', 'Cold Mountain']
#   science fiction, action  (3 movies)  e.g. ['Godzilla vs. Megaguirus', 'Gunhed', 'Star Wars: Episode III – Revenge of the Sith']
#   fantasy adventure     (3 movies)  e.g. ['Ajooba', 'The BFG', 'The Fall']
#   dance, drama          (3 movies)  e.g. ['Battle of the Year', 'Feel the Noise', 'Stomp the Yard']
#   horror, mystery       (3 movies)  e.g. ['Case 39', 'It Comes at Night', 'The Tall Man']
#   action, spy film      (3 movies)  e.g. ['Bourne Legacy, TheThe Bourne Legacy', 'Green Zone', 'Mission: Impossible – Ghost Protocol']
#   biopic, drama         (3 movies)  e.g. ['J. Edgar', 'Mahanayak Vasant Tu', 'Soul Surfer']
#   anthology, horror     (3 movies)  e.g. ['ABCs of Death, TheThe ABCs of Death', 'V/H/S', 'V/H/S/2']
#   animation adventure   (3 movies)  e.g. ['Finding Dory', 'The Book of Life', 'Zootopia']
#   animation comedy      (3 movies)  e.g. ['Big Hero 6', 'Mary and Max', 'Norm of the North']
#   superhero action adventure  (3 movies)  e.g. ['Captain America: Civil War', 'Suicide Squad', 'X-Men: Apocalypse']
#   thriller, fantasy     (3 movies)  e.g. ['American Fable', 'Naksha', 'Nanjupuram']
#   crime, drama, mystery  (3 movies)  e.g. ['2001: Do Hazaar Ek', 'Crooked House', 'The Stoneman Murders']
#   drama / thriller      (3 movies)  e.g. ['Fatal Bond', 'Turtle Beach', 'Wake in Fright']
#   music                 (3 movies)  e.g. ['ABBA: The Movie', 'Bharya Biddalu', 'Jeevitha Chakram']
#   crime / drama         (3 movies)  e.g. ['A Chilling Cosplay', 'Backlash', 'Weekend of Shadows']
#   action / crime / drama  (3 movies)  e.g. ["Heaven's Burning", 'Jagat', 'The Viral Factor']
#   drama / comedy / romance  (3 movies)  e.g. ['Thank God He Met Lizzie', 'Tiny Times 3', 'Tiny Times 4']
#   mystery/thriller      (3 movies)  e.g. ['Bunny Lake Is Missing', 'Murder!', 'Sleuth']
#   musical/drama         (3 movies)  e.g. ['Big Fella', "It Couldn't Happen Here", 'Kaanchi...']
#   fantasy/adventure     (3 movies)  e.g. ['Freddie as F.R.O.7', 'Sheena', 'The Thief of Bagdad']
#   musical/romance       (3 movies)  e.g. ['Bekhudi', 'Sapne Sajan Ke', 'The Lady Is a Square']
#   comedy/satire         (3 movies)  e.g. ['Four Lions', 'Jolly LLB', 'The Rise and Rise of Michael Rimmer']
#   crime/romance         (3 movies)  e.g. ['Captives', 'Once Upon Ay Time In Mumbai Dobaara!', 'Tamanchey']
#   nfb animated short    (3 movies)  e.g. ['Bead Game', 'Special Delivery', 'The Sand Castle']
#   romantic comedy, drama  (3 movies)  e.g. ['101 Weddings', 'Ami Shudhu Cheyechi Tomay', 'Bollywood/Hollywood']
#   sci-fi fantasy        (3 movies)  e.g. ['Beyond the Black Rainbow', 'Enoshima Prism', 'Mars et Avril']
#   horror drama          (3 movies)  e.g. ['Enga Amma Rani', 'Om Shanti Om', 'Ravenous (Les Affamés)']
#   historical/action     (3 movies)  e.g. ['14 Blades', 'True Legend', 'Warriors of Heaven and Earth']
#   drama/history         (3 movies)  e.g. ['Chauthi Koot', 'Palnati Yudham', 'Sacrifice']
#   action / crime / thriller  (3 movies)  e.g. ['Heroic Duo', 'Protégé', 'Special ID']
#   action / fantasy      (3 movies)  e.g. ['The Great Magician', 'The Monkey King', 'The Thousand Faces of Dunjia']
#   mystery / thriller    (3 movies)  e.g. ['Bunshinsaba 3', 'Massagist', 'Midnight Hair']
#   drama / family        (3 movies)  e.g. ['Dearest', 'Forgetting to Know You', 'Mountains May Depart']
#   drama / mystery / crime  (3 movies)  e.g. ['12 Citizens', 'The Dead End', 'The Witness']
#   action / adventure / martial arts  (3 movies)  e.g. ['Kung Fu Dunk', 'Legend of the Fist: The Return of Chen Zhen', 'The Winged Tiger']
#   erotic / drama        (3 movies)  e.g. ['3D Sex and Zen: Extreme Ecstasy', 'The Gigolo', 'The Gigolo 2']
#   -                     (3 movies)  e.g. ['Jhinder Bandi', 'Saptapadi', 'Teen Kanya']
#   action/romance/comedy  (3 movies)  e.g. ['Chirodini Tumi Je Amar', 'Chirosathi', 'Premer Kahini']
#   costume action        (3 movies)  e.g. ['Daku Mansoor', 'Samrat', 'Shahenshah']
#   drama, musical, romance  (3 movies)  e.g. ['Ijaazat', 'Love Story 2050', 'Tansen']
#   social family         (3 movies)  e.g. ['Bazaar', 'School Master', 'Sujata']
#   thriller romance      (3 movies)  e.g. ['House No. 44', 'Munimji', 'Singapore']
#   social romance        (3 movies)  e.g. ['Anari', 'Chhalia', 'Shree 420']
#   drama, mystery, thriller  (3 movies)  e.g. ['Aakrosh', 'Shart', 'Via Darjeeling']
#   action, crime, romance  (3 movies)  e.g. ['Kabhi Na Kabhi', 'Milan', 'Rajput']
#   comedy, romance, musical  (3 movies)  e.g. ['Ghar Ki Izzat', 'Lakhon Ki Baat', 'Mujhse Shaadi Karogi']
#   romance, action, comedy  (3 movies)  e.g. ['Library Wars: The Last Mission', 'Ram Lakhan', 'Teja Bhai & Family']
#   action, romance, drama  (3 movies)  e.g. ['Angaaraka', 'Ek Anari Do Khiladi', 'Ninnindale']
#   historical, drama     (3 movies)  e.g. ['In This Corner of the World', 'Satoshi: A Move for Tomorrow', 'The Legend of Bhagat Singh']
#   romance, drama, comedy  (3 movies)  e.g. ['Kyun...! Ho Gaya Na', 'Main Prem Ki Diwani Hoon', 'Spanish Masala']
#   politics              (3 movies)  e.g. ['Davpech', 'Deshdrohi', 'Zenda']
#   political satire      (3 movies)  e.g. ['Ekkees Toppon Ki Salaami', 'Gaon Thor Pudhari Chor', 'Saguni']
#   heist                 (3 movies)  e.g. ['ATM', 'Kohinoor', 'Rajathandhiram']
#   action, masala        (3 movies)  e.g. ['Singam Puli', 'Siruthai', 'Thambikottai']
#   drama-thriller        (3 movies)  e.g. ['Chennaiyil Oru Naal', 'Malini 22 Palayamkottai', 'Papanasam']
#   action & romance      (3 movies)  e.g. ['Loafer', 'Sher', 'Soukhyam']
#   roman porno           (3 movies)  e.g. ['A Woman Called Sada Abe', 'Tokyo Emmanuelle', 'Watcher in the Attic']
#   sci-fi for children   (3 movies)  e.g. ['Dynaman Movie', 'Goggle V Movie', 'JAKQ Dengeki Tai vs. Goranger']
#   anime for children    (3 movies)  e.g. ['Kinnikuman the Movie: Great Riot! Justice Superman', 'Kinnikuman the Movie: Stolen Championship Belt', 'Mobile Suit Gundam III: Encounter in Space']
#   supernatural/action/anime  (3 movies)  e.g. ['BLEACH the Movie: Memories of Nobody', 'BLEACH the Movie: The DiamondDust Rebellion', 'Bleach: Fade to Black']
#   science fiction, mystery  (3 movies)  e.g. ['20th Century Boys 1: Beginning of the End', '20th Century Boys 2: The Last Hope', '20th Century Boys 3: Redemption']
#   anime fantasy         (3 movies)  e.g. ["Magical Girl Lyrical Nanoha The Movie 2nd A's", 'Majocco Shimai no Yoyo to Nene', 'Patema Inverted']
#   horror, psychological thriller, drama, dark fantasy  (3 movies)  e.g. ['Kizumonogatari Part 1: Tekketsu', 'Kizumonogatari Part 2: Nekketsu', 'Kizumonogatari Part 3: Reiketsu']
#   historical, fantasy, adventure, action, science fantasy, superheroes  (3 movies)  e.g. ['Fullmetal Alchemist', 'The Dragon Dentist', 'Touken Ranbu: Hanamaru ~Makuai Kaisōroku~']
#   adventure, thriller   (2 movies)  e.g. ['Run for the Sun', 'The Most Dangerous Game']
#   historical comedy     (2 movies)  e.g. ['Imsai Arasan 23m Pulikesi', 'The Affairs of Cellini']
#   adventure, action     (2 movies)  e.g. ['Captain Blood', 'The Three Musketeers']
# ...
#   sunil, arti agarwal   (1 movies)  e.g. ['18']
#   mohit ahlawat, priyanka kothari  (1 movies)  e.g. ['14']
#   chiranjeevi, trisha krishnan, khushboo  (1 movies)  e.g. ['20']
#   indira amperiani, bhaskara s. narayanan  (1 movies)  e.g. ['21']
#   nagarjuna, shriya saran, nayantara, poonam bajwa  (1 movies)  e.g. ['27']
#   sumanth, charmme      (1 movies)  e.g. ['27']
#   sivaji, krishna bhagavaan, ali  (1 movies)  e.g. ['12']
#   srikanth, venu madhav, ali  (1 movies)  e.g. ['19']
#   rajendra prasad       (1 movies)  e.g. ['16']
#   bharath, arya, pooja, padmapriya  (1 movies)  e.g. ['21']
#   raja, bhoomika chawla, s. p. balu  (1 movies)  e.g. ['16']
#   ravi teja, ileana d'cruz  (1 movies)  e.g. ['14']
#   jr. ntr, charmy kaur, ileana d'cruz  (1 movies)  e.g. ['22']
#   uday kiran, vimala raman  (1 movies)  e.g. ['23']
#   pawan kalyan, asin, sandhya  (1 movies)  e.g. ['29']
#   balakrishna nandamuri, sneha, tabu  (1 movies)  e.g. ['30']
#   buddy film            (1 movies)  e.g. ['Ankit, Pallavi & Friends']
#   srikanth, bhavana     (1 movies)  e.g. ['9']
#   fantasy, action       (1 movies)  e.g. ['Anagananga Oka Dheerudu']
#   action, period film   (1 movies)  e.g. ['Urumi']
#   mythology (fiction)   (1 movies)  e.g. ['Sri Rama Rajyam']
#   action entertainer    (1 movies)  e.g. ['Shadow']
#   devotional biography  (1 movies)  e.g. ['Jagadguru Adi Shankara']
#   adult romance         (1 movies)  e.g. ['Madhumati']
#   drama thriller        (1 movies)  e.g. ['Malini 22 Vijayawada']
#   psychological action thriller  (1 movies)  e.g. ['1: Nenokkadine']
#   epic-historical film  (1 movies)  e.g. ['Baahubali: The Beginning']
#   action & comedy       (1 movies)  e.g. ['Bruce Lee']
#   horror – thriller     (1 movies)  e.g. ['Tripura']
#   action-love           (1 movies)  e.g. ['Shourya']
#   horror - thriller     (1 movies)  e.g. ['Abhinetri']
#   romance - thriller    (1 movies)  e.g. ['Ekkadiki Pothavu Chinnavada']
#   action - thriller     (1 movies)  e.g. ['Dhruva']
#   love story            (1 movies)  e.g. ['Janaki Ramudu']
#   drama-comedy-social   (1 movies)  e.g. ['Karam Dosa']
#   devotional-biographical  (1 movies)  e.g. ['Om Namo Venkatesaya']
#   inspired by true event  (1 movies)  e.g. ['Ghazi']
#   sci-fi thriller       (1 movies)  e.g. ['Okka Kshanam']
#   crime, drama, mystery, jidaigeki  (1 movies)  e.g. ['Rashomon']
#   keiji                 (1 movies)  e.g. ['Varan the Unbelievable']
#   war drama[not in citation given]  (1 movies)  e.g. ['Fires on the Plain']
#   comedy[not in citation given]  (1 movies)  e.g. ['Good Morning']
#   science fiction[not in citation given]  (1 movies)  e.g. ['Human Vapor !The Human Vapor']
#   erotic film           (1 movies)  e.g. ['Flesh Market']
#   period film           (1 movies)  e.g. ['Onibaba']
#   jidai-geki            (1 movies)  e.g. ['Portrait of Hell']
#   chanbara              (1 movies)  e.g. ['Lady Snowblood']
#   mocatsu               (1 movies)  e.g. ['Gorenger the Movie']
#   anime war drama       (1 movies)  e.g. ['Barefoot Gen']
#   docufiction drama     (1 movies)  e.g. ['Nankyoku Monogatari']
#   fantasy, horror, science fiction  (1 movies)  e.g. ['Vampire Hunter D']
#   animation/fantasy     (1 movies)  e.g. ['Castle in the Sky']
#   animation/fighting/fantasy  (1 movies)  e.g. ['Dragon Ball: Curse of the Blood Rubies']
#   animation/fighting    (1 movies)  e.g. ['Fist of the North Star']
#   magical girl, family, drama  (1 movies)  e.g. ['Esper Mami: Hoshizora no Dancing Doll[4]']
#   anime martial arts    (1 movies)  e.g. ['Dragon Ball Z: Dead Zone']
#   comedy, drama, science fiction  (1 movies)  e.g. ['Maroko']
#   anime drama mystery fantasy  (1 movies)  e.g. ["Mermaid's Scar"]
#   yakuza film           (1 movies)  e.g. ['Sonatine']
#   drama, anime          (1 movies)  e.g. ['Millennium Actress']
#   fantasy, martial arts  (1 movies)  e.g. ['Onmyoji']
#   comedy drama anime    (1 movies)  e.g. ['Tokyo Godfathers']
#   school, sports        (1 movies)  e.g. ['The Prince of Tennis']
#   horror film           (1 movies)  e.g. ['Retribution']
#   romantic comedy, school, sports  (1 movies)  e.g. ['Rough']
#   anime/computer animation  (1 movies)  e.g. ['Appleseed Ex Machina : The Movie']
#   tokusatsu v-cinema    (1 movies)  e.g. ['GoGo Sentai Boukenger vs. Super Sentai']
#   computer animation    (1 movies)  e.g. ['Vexille']
#   erotic horror         (1 movies)  e.g. ['Cruel Restaurant']
#   science fiction, time travel  (1 movies)  e.g. ['Cyborg She']
#   romance, comedy, drama, art house & international, action  (1 movies)  e.g. ['Love Exposure']
#   horror, action comedy  (1 movies)  e.g. ['The Machine Girl']
#   ken'ichi maysuyama, koyuki  (1 movies)  e.g. ['000000002018-09-19-000019 September']
#   gore film             (1 movies)  e.g. ['Samurai Princess']
#   splatter              (1 movies)  e.g. ['Mutant Girls Squad']
#   gangster black comedy  (1 movies)  e.g. ['Outrage']
#   anime science fiction  (1 movies)  e.g. ['Planzet']
#   costume martial arts  (1 movies)  e.g. ['Thirteen Assassins']
#   anime drama           (1 movies)  e.g. ['From up on Poppy Hill']
#   splatter comedy       (1 movies)  e.g. ['Deadball']
#   erotic, romance, comedy  (1 movies)  e.g. ['Nozoki Ana']
#   anime action adventure  (1 movies)  e.g. ['The Last: Naruto the Movie']
#   dystopia, crime, cyberpunk  (1 movies)  e.g. ['Psycho-Pass: The Movie']
#   superheroes, tokusatsu  (1 movies)  e.g. ["Nobita's Space Hero Record of Space Heroes"]
#   vampire film          (1 movies)  e.g. ['Koisuru Vampire']
#   youth drama           (1 movies)  e.g. ['Flying Colors']
#   historical anime      (1 movies)  e.g. ['Miss Hokusai']
#   youth music drama     (1 movies)  e.g. ['Love Live! The School Idol Movie']
#   suspense action horror  (1 movies)  e.g. ['Tag']
#   sports (road bicycle racing)  (1 movies)  e.g. ['Yowamushi Pedal: The Movie']
#   school, action, drama  (1 movies)  e.g. ['Girls und Panzer der Film']
#   teen fantasy drama    (1 movies)  e.g. ['Orange']
#   fantasy, drama, sci-fi, magical girl, superheroes, spy  (1 movies)  e.g. ['Garakowa: Restore the World']
#   drama, comedy-drama, action  (1 movies)  e.g. ['Pink and Gray']
#   political, neo-noir, supernatural, spy, action  (1 movies)  e.g. ['Persona 3 The Movie: No. 4, Winter of Rebirth']
#   historical, drama, musical  (1 movies)  e.g. ['Nobunaga Concerto']
#   drama, comedy, action, magical girl  (1 movies)  e.g. ["Tantei Opera Milky Holmes the Movie: Milky Holmes' Counterattack"]
#   historical, drama, action, superheroes, spy, sci-fi  (1 movies)  e.g. ['Doraemon: Nobita and the Birth of Japan 2016 and Infinimals Roaring Skies']
#   dance, idol, magical girl, musical  (1 movies)  e.g. ["PriPara Mi~nna no Akogare Let's Go PriPari"]
#   political, fantasy, drama, mystery, thriller  (1 movies)  e.g. ['Boku Dake ga Inai Machi and the Binding of Tony Blair']
#   drama, youth, sports (children's poker, karuta)  (1 movies)  e.g. ['Chihayafuru Part 1 and 2']
#   drama, youth, musical  (1 movies)  e.g. ['Gekijō-ban Hibike! Euphonium ~ Kitauji Kōkō Suisōraku-Bu e Yōkoso~']
#   fantasy, action, science fantasy, sci-fi  (1 movies)  e.g. ['Yu-Gi-Oh!: The Dark Side of Dimensions']
#   horror, drama, action, sci-fi  (1 movies)  e.g. ['I Am a Hero and and I’m a Dune Space']
#   drama, comedy-drama, science fantasy  (1 movies)  e.g. ['After the Storm']
#   political, drama, comedy, romantic comedy  (1 movies)  e.g. ['Wolf Girl and Black Prince']
#   fantasy, drama, romance, sci-fi  (1 movies)  e.g. ['Mars: Tada, Kimi wo Aishiteru']
#   fantasy, action, comedy, comedy-drama, drama, science fantasy  (1 movies)  e.g. ['Kingsglaive: Final Fantasy XV']
#   fantasy, drama, action, spy, superheroes, tokusatsu  (1 movies)  e.g. ['One Piece Film: Gold']
#   drama, sci-fi, kaiju, action  (1 movies)  e.g. ['Shin Godzilla']
#   drama, adventure, children's  (1 movies)  e.g. ['Rudolf the Black Cat']
#   drama, comedy-drama, romance, musical, idol, youth  (1 movies)  e.g. ['Aozora Yell']
#   drama, comedy, romance, action, superheroes, spy  (1 movies)  e.g. ['James Black and the New Treasure and Your Lie in April']
#   political, drama, crime, thriller, neo-noir, supernatural  (1 movies)  e.g. ['Rage']
#   political, drama, crime, mystery  (1 movies)  e.g. ["Night's Tightrope"]
#   drama, comedy, comedy-drama, slice of life  (1 movies)  e.g. ['My Dad and Mr. Ito']
#   drama, crime, sci-fi, action, supeheroes, spy  (1 movies)  e.g. ['GANTZ: O and Morrison Steel: The Greatest Years of My Life']
#   action, sci-fi, mecha  (1 movies)  e.g. ['Zegapain ADP']
#   horror, thriller, supernatural, action, monster  (1 movies)  e.g. ['Death Note: Light Up the New World']
#   drama, action, supernatural, sci-fi, spy  (1 movies)  e.g. ["Kagerou Daze -in a day's-"]
#   action, sci-fi, mecha, spy  (1 movies)  e.g. ['Galactic Armored Fleet Majestic Prince: Genetic Awakening']
#   horror, drama, supernatural horror, thriller  (1 movies)  e.g. ['Museum']
#   fantasy, drama, romance, slice of life  (1 movies)  e.g. ['My Tomorrow, Your Yesterday']
#   drama, comedy, action, spy, sci-fi, superheroes  (1 movies)  e.g. ['The Mole Song: Hong Kong Capriccio']
#   horror, post-apocalyptic, steampunk, action  (1 movies)  e.g. ['Kabaneri of the Iron Fortress Pt.1']
#   horror, post-apocalyptic, steampunk, spy, action  (1 movies)  e.g. ['Kabaneri of the Iron Fortress Pt.2']
#   fantasy, drama, comedy, mystery  (1 movies)  e.g. ['Honnōji Hotel']
#   drama, tokusatsu, action, sci-fi  (1 movies)  e.g. ["Doubutsu Sentai Zyuohger vs. Ninninger the Movie: Super Sentai's Message from the Future"]
#   historical, psychological thriller, black comedy, dark fantasy, science fantasy  (1 movies)  e.g. ['Black Butler: Book of the Atlantic']
#   drama, action, sci-fi, spy  (1 movies)  e.g. ['Genocidal Organ']
#   horror comedy, horror, drama, monster  (1 movies)  e.g. ['Ao Oni The Animation']
#   fantasy, action, adventure, science fantasy, sci-fi, superheroes  (1 movies)  e.g. ['Sword Art Online The Movie: Ordinal Scale']
#   drama, comedy-drama, romance, youth, slice of life, science fantasy  (1 movies)  e.g. ['One Week Friends']
#   drama, comedy-drama, romantic comedy  (1 movies)  e.g. ['Kyō no Kira-kun']
#   harem, fantasy, action, drama, romantic comedy, magical girl  (1 movies)  e.g. ["Trinity Seven the Movie: The Eternal Library and the Alchemist Girl and The Smith's Fantasy Series"]
#   drama, comedy-drama, musical, mystery  (1 movies)  e.g. ['Haruta & Chika']
#   dance, musical, idol  (1 movies)  e.g. ['PriPara the Movie: Everyone Shine! Kirarin Star Live']
#   adventure, children's, drama, sci-fi  (1 movies)  e.g. ['Doraemon the Movie 2017: Great Adventure in the Antarctic Kachi Kochi']
#   drama, children's, science fantasy, sci-fi  (1 movies)  e.g. ['Ancien and the Magic Tablet (a.k.a. Napping Princess)']
#   fantasy, action, comedy, comedy-drama, drama, magical girl  (1 movies)  e.g. ['Yuki Yuna wa Yūsha-bu Shozoku and Yuki Yuna: Washio Sumi Chapter Series']
#   fantasy, drama, science fantasy  (1 movies)  e.g. ['The Night Is Short, Walk on Girl']
#   drama, sports (aquatics, swimming), comedy-drama  (1 movies)  e.g. ['Free! -Timeless Medley-']
#   fantasy, children's, action, comedy, comedy-drama, slice of life  (1 movies)  e.g. ['Eiga Tamagotchi: Himitsu no Otodake Daisakusen!']
#   horror, fantasy, chanbara, supernatural, jidaigeki, action  (1 movies)  e.g. ['Blade of the Immortal']
#   drama, comedy-drama, comedy  (1 movies)  e.g. ['Teiichi: Battle of Supreme High']
#   fantasy, action, drama, adventure, mystery, spy  (1 movies)  e.g. ['Fairy Tail: Dragon Cry']
#   action, sci-fi, comedy, spy, tokusatsu  (1 movies)  e.g. ['Hurricane Polymar']
#   drama, comedy-drama, romance, youth, slice of life  (1 movies)  e.g. ['Peach Girl and GJS Returns 4 Trilogy']
#   sci-fi, action, spy   (1 movies)  e.g. ['Blame!']
#   drama, children's, musical  (1 movies)  e.g. ['Lu Over the Wall']
#   horror, supernatural horror, action  (1 movies)  e.g. ['Resident Evil: Vendetta']
#   drama, romance, sci-fi  (1 movies)  e.g. ['A Beautiful Star']
#   political, drama, action, sci-fi, mystery, thriller  (1 movies)  e.g. ['Confession of Murder (a.k.a. Memoirs of a Murderer)']
#   fantasy, action, science fantasy, sci-fi, spy, superheroes  (1 movies)  e.g. ['The Irregular at Magic High School The Movie: The Girl Who Calls the Stars']
#   tokusatsu, action, sci-fi, spy, superheroes  (1 movies)  e.g. ['Space Squad']
#   fantasy, drama, children's, magical girl, science fantasy  (1 movies)  e.g. ["Mary and the Witch's Flower"]
#   historical, chanbara, comedy, jidaigeki, tokusatsu, science fantasy  (1 movies)  e.g. ['Gintama']
#   comedy, romance, slice of life  (1 movies)  e.g. ['Seitokai Yakuindomo']
#   drama, romance, youth, sci-fi, slice of life  (1 movies)  e.g. ['The Anthem of the Heart']
#   horror, dark fantasy, supernatural horror, action, monster, spy  (1 movies)  e.g. ['Tokyo Ghoul']
#   horror, action, supernatural, thriller, tokusatsu, drama  (1 movies)  e.g. ["JoJo's Bizarre Adventure: Diamond Is Unbreakable Chapter I"]
#   drama, sci-fi, comedy, youth, slice of life  (1 movies)  e.g. ['Fireworks, Should We See It from the Side or the Bottom? and Raving Jeff’s Stronger Battle']
#   fantasy, drama, action, magical girl, science fantasy, spy  (1 movies)  e.g. ['Fate/kaleid liner Prisma Illya: Oath Under Snow']
#   thriller, drama, sci-fi  (1 movies)  e.g. ['The Third Murder']
#   drama, action, sports (volleyball)  (1 movies)  e.g. ['Haikyū Third Season Movie']
#   drama, youth, musical, romance, idol  (1 movies)  e.g. ['Sound! Euphonium: Todoketai Melody!']
#   horror, action, monster, thriller, supernatural, spy  (1 movies)  e.g. ['Ajin']
#   drama, crime, thriller, sci-fi, action, spy  (1 movies)  e.g. ['Outrage Coda']
#   horror, fantasy, action, magical girl, science fantasy, spy  (1 movies)  e.g. ["Fate/stay night: Heaven's Feel Series"]
#   drama, sports (road bicycle racing), comedy-drama  (1 movies)  e.g. ['Yowamushi Pedal: Re:GENERATION!']
#   fantasy, sci-fi, action, mecha, supernatural  (1 movies)  e.g. ['Code Geass Lelouch of the Resurrection the Movie: Awakening Path']
#   drama, slice of life, sports (aquatics, swimming), comedy-drama  (1 movies)  e.g. ['Free! -Take Your Marks!-']
#   drama, children's, comedy-drama, youth, romance, slice of life  (1 movies)  e.g. ['My Teacher']
#   drama, romance, youth, mystery  (1 movies)  e.g. ['Hyouka']
#   fantasy, drama, dance, musical, romance, idol  (1 movies)  e.g. ['Dance with Devils: Fortuna']
#   historical, drama, comedy-drama, romance, youth  (1 movies)  e.g. ['Gekijōban Haikara-san ga Tōru Zenpen ~Benio, Hana no 17-sai~']
#   drama, kaiju, mecha, space opera, sci-fi, action  (1 movies)  e.g. ['Godzilla: Planet of the Monsters']
#   drama, action, military, spy  (1 movies)  e.g. ['Girls und Panzer das Finale']
#   fantasy, drama, children's, sci-fi, adventure, spy  (1 movies)  e.g. ['Yo-kai Watch Shadowside: Oni-ō no Fukkatsu']
#   action / historical   (1 movies)  e.g. ['Leftenan Adnan']
#   comedy / drama / romance  (1 movies)  e.g. ['Mukhsin']
#   historical / action / war  (1 movies)  e.g. ['Hikayat Merong Mahawangsa']
#   devotional horror     (1 movies)  e.g. ['Vettai Karuppar Ayya']
#   dark slasher          (1 movies)  e.g. ['The Farm: En Veettu Thottathil']
#   sport drama           (1 movies)  e.g. ['Shadowboxing']
#   history, spy          (1 movies)  e.g. ['The Turkish Gambit']
#   history, fantasy      (1 movies)  e.g. ['Prince Vladimir']
#   historical fantasy    (1 movies)  e.g. ['1612']
#   action, science fiction, thriller  (1 movies)  e.g. ['Paragraph 78']
#   historical adventure  (1 movies)  e.g. ["The Sovereign's Servant"]
#   historical, action    (1 movies)  e.g. ['Alexander']
#   children's science fiction  (1 movies)  e.g. ["Alice's Birthday"]
#   musical, adventure    (1 movies)  e.g. ['The Return of the Musketeers']
#   olga khokhlova, sergey krapiventsev, oleg sukachenko  (1 movies)  e.g. ['Цветок дьявола']
#   adventure, drama film  (1 movies)  e.g. ['Territory']
#   sport film            (1 movies)  e.g. ['Warrior']
#   animation, produced by glukoza production  (1 movies)  e.g. ["A Warrior's Tail"]
#   adventure, romance, fantasy film  (1 movies)  e.g. ["He's a Dragon"]
#   horror romantic comedy  (1 movies)  e.g. ['Spellbound']

# %% [markdown]
# ## Now its your turn!

# %% [markdown]
# ### Task 1
#
# - Calculate the Average Plot Length per Origin/Ethnicity
#
# **Concept:** The mapper emits a *tuple* as the value — not just a `1`.
# Without this trick, the reducer cannot compute an average because it would have lost how many movies contributed to a total.
#
# **The naïve wrong approach:**
# Emit `(Origin, word_count)` → reduce by summing → this gives the *total* words, not the *average*.
#
# **The correct approach — emit a (sum, count) pair:**
# ```
# MAP emits:     (Origin, (word_count, 1))
# SHUFFLE gives: Origin → [(500, 1), (320, 1), (410, 1), ...]
# REDUCE does:   total_words = sum of all first elements
#                total_movies = sum of all second elements
#                average = total_words / total_movies
# ```
#
# > This pattern — emitting partial aggregates — is fundamental to distributed computing.
# > You will see it again in frameworks like Spark and Flink.

# %%
# ── Mapper ───────────────────────────────────────────────────────────────────
def plot_length_mapper(row):
    """
    Emits (origin, (word_count, 1)) — a tuple as the value.

    word_count counts the whitespace-separated tokens in the plot.
    The '1' is the movie count contribution from this single row.
    Both are needed by the reducer to compute the average.
    """
    origin     = None # TODO
    plot       = None # TODO
    word_count = None # TODO
    return None # TODO


# ── Reducer ───────────────────────────────────────────────────────────────────
def avg_plot_length_reducer(key, values):
    """
    values is a list of (word_count, 1) tuples — one per movie for this origin.

    We unzip them into two lists, then compute the average:
        average = sum(word_counts) / sum(movie_counts)
    """
    total_words  = None # TODO
    total_movies = None # TODO
    average      = None # TODO
    return None # TODO


# ── Run ───────────────────────────────────────────────────────────────────────
results_task4 = None # TODO

# Sort by average plot length descending
results_task4_sorted = sorted(results_task4, key=lambda x: x[1], reverse=True)

print("Average plot length (words) per origin — sorted descending:\n")
for origin, avg in results_task4_sorted:
    print(f"  {origin:<30}  {avg:>8.1f} words")

# %% [markdown]
# ### Task 2
#
# - Calculate Most Prolific Director per Decade (2 MapReduce Jobs)
#
# **Concept:** Some problems cannot be solved in a single MapReduce pass.
# Here we need two chained jobs:
#
# ```
# JOB 1: Count movies per (Decade, Director)
# ─────────────────────────────────────────────────────────────────────────
# MAP 1    →  ((decade, director), 1)
# REDUCE 1 →  ((decade, director), total_movies)
#
# JOB 2: Find the top director for each decade
# ─────────────────────────────────────────────────────────────────────────
# MAP 2    →  (decade, (director, total_movies))   ← reshape the key
# REDUCE 2 →  (decade, top_director)               ← argmax over values
# ```
#
# **Why can't we do this in one pass?**
# After Job 1 the data looks like `{("1940s", "John Ford"): 12, ("1940s", "Howard Hawks"): 8, ...}`.
# To find the *maximum within a decade* we need to group by decade alone — which requires a second shuffle.
#
# > **Note on the `Director` column:** It sometimes contains multiple comma-separated names
# > (e.g. `"George S. Fleming, Edwin S. Porter"`). The mapper splits on commas and credits
# > each director individually.

# %% [markdown]
# #### Job 1 count movies per (decade, director)

# %%
def director_decade_mapper(row):
    """
    Emits ((decade_label, director_name), 1) for every director credited on a film.

    A single movie can credit multiple directors (comma-separated), so this mapper
    may emit more than one pair per input row.
    """
    try:
       # something
    except # something
    raw_directors = None # TODO
    # Split on comma; strip whitespace; skip empty/placeholder values
    directors = None # TODO

    # if not directors:
    #     directors = ["Unknown"]

    return None # TODO


def sum_reducer(key, values):
    """Generic summation reducer — works for any numeric list."""
    # TODO


job1_results = None # TODO
# job1_results is a list of  ((decade, director), count)

# %% [markdown]
# #### JOB 2 — find the top director within each decade

# %%
def top_director_mapper(record):
    """
    Reshapes the output of Job 1.
    Input:  ((decade, director), total_movies)
    Output: (decade, (director, total_movies))

    We change the key from (decade, director) → decade only so that the
    shuffle phase groups ALL directors for a decade together.
    """
    (decade, director), total_movies = None # TODO
    return None # TODO


def top_director_reducer(key, values):
    """
    Receives all (director, total_movies) tuples for a single decade.
    Returns the director with the highest movie count (argmax).
    """
    best_director, best_count = None # TODO
    return None # TODO


job2_results = None # TODO

# Sort chronologically
job2_sorted = list(None) # TODO

print("Most prolific director per decade:\n")
for decade, info in job2_sorted:
    print(f"  {decade}  →  {info}")

# %% [markdown]
# ### Task 3
# - Calculate Directors with the Most Diverse Genre Portfolio (2 MapReduce Jobs)
#
# **Concept:** The classic **Count Distinct** problem in distributed systems.
#
# **Why can't this be done in one pass?**
# If we emit `(director, 1)` once per movie, a director with 5 westerns would be counted 5 times for that genre.
# We need to deduplicate `(Director, Genre)` pairs *before* counting.
#
# ```
# JOB 1: Deduplicate (Director, Genre) pairs
# ─────────────────────────────────────────────────────────────────────────────────
# MAP 1    →  ((director, genre), 1)       ← composite key
# REDUCE 1 →  (director, 1)               ← ONE '1' per unique pair, regardless of sum
#
# JOB 2: Count how many unique genres each director has worked in
# ─────────────────────────────────────────────────────────────────────────────────
# MAP 2    →  (director, 1)               ← identity mapper
# REDUCE 2 →  (director, total_unique_genres)
# ```
#
# **The trick in Job 1:** The reducer ignores the sum entirely.
# The *grouping by composite key* in the shuffle phase is what performs the deduplication — each unique `(director, genre)` pair arrives at exactly one reducer, which emits exactly one `1`.

# %% [markdown]
# #### Job 1: Deduplicate (Director, Genre) pairs

# %%
def director_genre_mapper(row):
    """
    Emit a ((director, genre), 1) pair for each director involved in a movie.
    - Splits multi-director cells on commas (e.g. "Spielberg, Lucas").
    - Uses a composite key so the shuffle groups by (director, genre) — this
      is what deduplicates: a director who made 10 westerns still yields only
      ONE entry for ("Director", "western") after the shuffle.
    """
    directors = None # TODO
    genre = None # TODO
    return None # TODO


def dedup_reducer(key, values):
    """
    key    = (director, genre)  — already unique after shuffle
    values = [1, 1, ...]        — how many movies; we IGNORE the count
    Returns (director, 1) — one credit toward genre diversity, guaranteed unique.
    """
    director, genre = None # TODO
    return None # TODO


job1_t6 = None # TODO

print(f"Job 1 produced {len(job1_t6):,} unique (director, genre) pairs")
print("Sample:", job1_t6[:5])

# %% [markdown]
# #### Job 2: Sum unique-genre credits per director

# %%
def identity_mapper_t6(record):
    """
    The input is already a (director, 1) tuple from Job 1.
    Nothing to transform — just wrap it in a list as our framework expects.
    """
    director, count = None # TODO
    return None # TODO


def sum_reducer_t6(key, values):
    """
    key    = director name
    values = [1, 1, 1, ...]  — one '1' per unique genre from Job 1
    Returns (director, total_unique_genres).
    """
    return None # TODO


job2_t6 = None # TODO

# ── Results ─────────────────────────────────────────────────────────────────
top_diverse = sorted(job2_t6, key=lambda x: x[1], reverse=True)

print("\n🎬 Top 20 Directors by Genre Diversity")
print(f"{'Director':<30} {'Unique Genres':>13}")
print("-" * 45)
for director, genres in top_diverse[:20]:
    print(f"{director:<30} {genres:>13}")
